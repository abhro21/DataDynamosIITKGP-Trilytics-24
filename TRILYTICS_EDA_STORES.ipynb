# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('final_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563113 entries, 0 to 563112
# Data columns (total 46 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Unnamed: 0                        563113 non-null  int64
#  1   STORE_KEY                         563113 non-null  int64
#  2   STORE_NUMBER                      563113 non-null  int64
#  3   STORE_NAME                        563113 non-null  object
#  4   STORE_TYPE_NAME                   563113 non-null  object
#  5   OPEN_DATE                         563113 non-null  object
#  6   CLOSE_DATE                        563113 non-null  object
#  7   BUSINESS_DATE                     563113 non-null  object
#  8   CITY_NAME                         563113 non-null  object
#  9   STATE_CODE                        563113 non-null  object
#  10  STATE_NAME                        563113 non-null  object
# ...

# %%
df.loc[ df[df['PROMOTION_OFFER'].isnull()].index , 'PROMOTION_OFFER'] = 'No Offers'
df.loc[ df[df['PROMOTION_ITEM'].isnull()].index , 'PROMOTION_ITEM'] = 'No Items'
df.loc[ df[df['PLATFORM'].isnull()].index , 'PLATFORM'] = 'No Platform'
df.loc[ df[df['FREQUENCY'].isnull()].index , 'FREQUENCY'] = 'None'
df.loc[ df[df['PROMOTION_COVERAGE'].isnull()].index , 'PROMOTION_COVERAGE'] = 'None'

# %%
dates = ['OPEN_DATE','CLOSE_DATE','BUSINESS_DATE','STORE_LIVE_DATE','DISPATCH_GO_LIVE_DATE','DOOR_DASH_GO_LIVE_DATE','DOOR_DASH_MARKUP_GO_LIVE_DATE','UBER_EATS_MARKUP_DATE']
for date in dates:
    df[date] = pd.to_datetime(df[date])

# %%
categorical_columns = ['STORE_TYPE_NAME' , 'CITY_NAME' , 'STATE_CODE' , 'STATE_NAME' , 'TIME_ZONE_NAME', 'DMA_NAME', 'STORE_STATUS', 'REGION_NAME', 'STORE_FUNCTIONAL_STATUS',
                       'GLOBAL_REGION_NAME', 'GLOBAL_REGION_STORE_TYPE_NAME', 'AREA_REGION', 'STORE_CONCEPT_NAME']
for i in categorical_columns:
  df[i] = df[i].astype('category')

# %%
df['STORE_KEY'] = df['STORE_KEY'].astype('int32')
df['STORE_NUMBER'] = df['STORE_NUMBER'].astype('int16')
df['DMA_ID'] = df['DMA_ID'].astype('int16')
df['REGION_ID'] = df['REGION_ID'].astype('int8')
df['TEMP_CLOSE_INDICATOR'] = df['TEMP_CLOSE_INDICATOR'].astype('int8')
df['PROJECTION_INCLUDED_INDICATOR'] = df['PROJECTION_INCLUDED_INDICATOR'].astype('int8')
df['BUSINESS_DATE_FISCAL_DAY_OF_YEAR'] = df['BUSINESS_DATE_FISCAL_DAY_OF_YEAR'].astype('int16')
df['BUSINESS_DATE_FISCAL_YEAR'] = df['BUSINESS_DATE_FISCAL_YEAR'].astype('int16')
df['COMP_BUSINESS_DATE_FISCAL_YEAR'] = df['COMP_BUSINESS_DATE_FISCAL_YEAR'].astype('int16')
df['COMPARABLE_INDICATOR'] = df['COMPARABLE_INDICATOR'].astype('int8')
df['TRANSACTION_FINAL_COUNT'] = df['TRANSACTION_FINAL_COUNT'].astype('int16')
df['NET_SALES_FINAL_USD_AMOUNT'] = df['NET_SALES_FINAL_USD_AMOUNT'].astype('int16')
df['PY_TRANSACTION_FINAL_COUNT'] = df['PY_TRANSACTION_FINAL_COUNT'].astype('int16')
df['PY_NET_SALES_FINAL_USD_AMOUNT'] = df['PY_NET_SALES_FINAL_USD_AMOUNT'].astype('int16')
df['PROMOTION_CASH_AMOUNT'] = df['PROMOTION_CASH_AMOUNT'].astype('int8')

# %%
categorical_columns1 = ['PROMOTION_TYPE', 'PROMOTION_OFFER', 'PROMOTION_ITEM', 'PLATFORM' , 'FREQUENCY', 'PROMOTION_COVERAGE']
for i in categorical_columns1:
  df[i] = df[i].astype('category')

# %%
df['PROMOTION_PERCENTAGE'] = pd.to_numeric(df['PROMOTION_PERCENTAGE'], downcast='float')
df['PRIOR_STORE_NUMBER'] = df['PRIOR_STORE_NUMBER'].astype('int8')

# %%
month_name_index = 7
day_name_index = 8
month_name = df['BUSINESS_DATE'].dt.month_name()
day_name = df['BUSINESS_DATE'].dt.day_name()
df.insert(loc = month_name_index, column = 'MONTH_NAME', value = month_name)
df.insert(loc = day_name_index, column = 'DAY_NAME', value = day_name)
df
# Out:
#         Unnamed: 0  STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  \
# 0                0        825             2        TX2       FRANCHISE
# 1                1        825             2        TX2       FRANCHISE
# 2                2        825             2        TX2       FRANCHISE
# 3                3        825             2        TX2       FRANCHISE
# 4                4        825             2        TX2       FRANCHISE
# ...            ...        ...           ...        ...             ...
# 563108      563108        791          7005     OH7005       FRANCHISE
# 563109      563109        791          7005     OH7005       FRANCHISE
# 563110      563110        791          7005     OH7005       FRANCHISE
# 563111      563111        791          7005     OH7005       FRANCHISE
# 563112      563112        791          7005     OH7005       FRANCHISE
#
#         OPEN_DATE CLOSE_DATE MONTH_NAME   DAY_NAME BUSINESS_DATE  ...  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.drop(columns = 'Unnamed: 0',inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563113 entries, 0 to 563112
# Data columns (total 47 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   STORE_KEY                         563113 non-null  int32
#  1   STORE_NUMBER                      563113 non-null  int16
#  2   STORE_NAME                        563113 non-null  object
#  3   STORE_TYPE_NAME                   563113 non-null  category
#  4   OPEN_DATE                         563113 non-null  datetime64[ns]
#  5   CLOSE_DATE                        563113 non-null  datetime64[ns]
#  6   MONTH_NAME                        563113 non-null  object
#  7   DAY_NAME                          563113 non-null  object
#  8   BUSINESS_DATE                     563113 non-null  datetime64[ns]
#  9   CITY_NAME                         563113 non-null  category
#  10  STATE_CODE                        563113 non-null  category
# ...

# %%
holidays_and_events_2019 = [
    '2019-01-01',  # New Year's Day
    '2019-01-21',  # Martin Luther King Jr. Day
    '2019-02-03',  # Super Bowl Sunday
    '2019-02-14',  # Valentine's Day
    '2019-02-18',  # Presidents' Day
    '2019-03-17',  # St. Patrick's Day
    '2019-04-21',  # Easter Sunday
    '2019-05-12',  # Mother's Day
    '2019-05-27',  # Memorial Day
    '2019-06-16',  # Father's Day
    '2019-07-04',  # Independence Day
    '2019-09-02',  # Labor Day
    '2019-10-14',  # Columbus Day
    '2019-10-31',  # Halloween
    '2019-11-11',  # Veterans Day
    '2019-11-28',  # Thanksgiving Day
    '2019-11-29',  # Black Friday
    '2019-11-30',  # Small Business Saturday
    '2019-12-02',  # Cyber Monday
    '2019-12-24',  # Christmas Eve
    '2019-12-25',  # Christmas Day
    '2019-12-31'   # New Year's Eve
]
holidays_and_events_2020 = [
    '2020-01-01',  # New Year's Day
    '2020-01-20',  # Martin Luther King Jr. Day
    '2020-02-02',  # Super Bowl Sunday
    '2020-02-14',  # Valentine's Day
    '2020-02-17',  # Presidents' Day
    '2020-03-17',  # St. Patrick's Day
    '2020-04-12',  # Easter Sunday
    '2020-05-10',  # Mother's Day
    '2020-05-25',  # Memorial Day
    '2020-06-21',  # Father's Day
    '2020-07-04',  # Independence Day
    '2020-09-07',  # Labor Day
    '2020-10-12',  # Columbus Day
    '2020-10-31',  # Halloween
    '2020-11-11',  # Veterans Day
    '2020-11-26',  # Thanksgiving Day
    '2020-11-27',  # Black Friday
    '2020-11-28',  # Small Business Saturday
    '2020-11-30',  # Cyber Monday
    '2020-12-24',  # Christmas Eve
    '2020-12-25',  # Christmas Day
    '2020-12-31'   # New Year's Eve
]

holidays_and_events_2021 = [
    '2021-01-01',  # New Year's Day
    '2021-01-18',  # Martin Luther King Jr. Day
    '2021-02-07',  # Super Bowl Sunday
    '2021-02-14',  # Valentine's Day
    '2021-02-15',  # Presidents' Day
    '2021-03-17',  # St. Patrick's Day
    '2021-04-04',  # Easter Sunday
    '2021-05-09',  # Mother's Day
    '2021-05-31',  # Memorial Day
    '2021-06-20',  # Father's Day
    '2021-07-04',  # Independence Day
    '2021-09-06',  # Labor Day
    '2021-10-11',  # Columbus Day
    '2021-10-31',  # Halloween
    '2021-11-11',  # Veterans Day
    '2021-11-25',  # Thanksgiving Day
    '2021-11-26',  # Black Friday
    '2021-11-27',  # Small Business Saturday
    '2021-11-29',  # Cyber Monday
    '2021-12-24',  # Christmas Eve
    '2021-12-25',  # Christmas Day
    '2021-12-31'   # New Year's Eve
]

holidays_and_events_2022 = [
    '2022-01-01',  # New Year's Day
    '2022-01-17',  # Martin Luther King Jr. Day
    '2022-02-13',  # Super Bowl Sunday
    '2022-02-14',  # Valentine's Day
    '2022-02-21',  # Presidents' Day
    '2022-03-17',  # St. Patrick's Day
    '2022-04-17',  # Easter Sunday
    '2022-05-08',  # Mother's Day
    '2022-05-30',  # Memorial Day
    '2022-06-19',  # Father's Day
    '2022-07-04',  # Independence Day
    '2022-09-05',  # Labor Day
    '2022-10-10',  # Columbus Day
    '2022-10-31',  # Halloween
    '2022-11-11',  # Veterans Day
    '2022-11-24',  # Thanksgiving Day
    '2022-11-25',  # Black Friday
    '2022-11-26',  # Small Business Saturday
    '2022-11-28',  # Cyber Monday
    '2022-12-24',  # Christmas Eve
    '2022-12-25',  # Christmas Day
    '2022-12-31'   # New Year's Eve
]

holidays_and_events_2023 = [
    '2023-01-01',  # New Year's Day
    '2023-01-16',  # Martin Luther King Jr. Day
    '2023-02-12',  # Super Bowl Sunday
    '2023-02-14',  # Valentine's Day
    '2023-02-20',  # Presidents' Day
    '2023-03-17',  # St. Patrick's Day
    '2023-04-09',  # Easter Sunday
    '2023-05-14',  # Mother's Day
    '2023-05-29',  # Memorial Day
    '2023-06-18',  # Father's Day
    '2023-07-04',  # Independence Day
    '2023-09-04',  # Labor Day
    '2023-10-09',  # Columbus Day
    '2023-10-31',  # Halloween
    '2023-11-11',  # Veterans Day
    '2023-11-23',  # Thanksgiving Day
    '2023-11-24',  # Black Friday
    '2023-11-25',  # Small Business Saturday
    '2023-11-27',  # Cyber Monday
    '2023-12-24',  # Christmas Eve
    '2023-12-25',  # Christmas Day
    '2023-12-31'   # New Year's Eve
]
# Convert to datetime
all_holidays_and_events = holidays_and_events_2019.copy()
all_holidays_and_events.extend(holidays_and_events_2020)
all_holidays_and_events.extend(holidays_and_events_2021)
all_holidays_and_events.extend(holidays_and_events_2022)
all_holidays_and_events.extend(holidays_and_events_2023)
all_holidays_and_events = pd.DatetimeIndex(all_holidays_and_events)

# %%
df.loc[df['BUSINESS_DATE'].isin(all_holidays_and_events), 'IS_HOLIDAY'] = 1

# %%
df.loc[~df['BUSINESS_DATE'].isin(all_holidays_and_events), 'IS_HOLIDAY'] = 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563113 entries, 0 to 563112
# Data columns (total 48 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   STORE_KEY                         563113 non-null  int32
#  1   STORE_NUMBER                      563113 non-null  int16
#  2   STORE_NAME                        563113 non-null  object
#  3   STORE_TYPE_NAME                   563113 non-null  category
#  4   OPEN_DATE                         563113 non-null  datetime64[ns]
#  5   CLOSE_DATE                        563113 non-null  datetime64[ns]
#  6   MONTH_NAME                        563113 non-null  object
#  7   DAY_NAME                          563113 non-null  object
#  8   BUSINESS_DATE                     563113 non-null  datetime64[ns]
#  9   CITY_NAME                         563113 non-null  category
#  10  STATE_CODE                        563113 non-null  category
# ...

# %%
spring_months = ['March' , 'April', 'May']
summer_months = ['June', 'July', 'August']
autum_months = ['September', 'October', 'November']
winter_months = ['December', 'January', 'February']

# %%
df.loc[ df[df['MONTH_NAME'].isin(summer_months)].index, 'SEASON' ] = 'Summer'
df.loc[ df[df['MONTH_NAME'].isin(spring_months)].index, 'SEASON' ] = 'Spring'
df.loc[ df[df['MONTH_NAME'].isin(autum_months)].index, 'SEASON' ] = 'Autumn'
df.loc[ df[df['MONTH_NAME'].isin(winter_months)].index, 'SEASON' ] = 'Winter'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563113 entries, 0 to 563112
# Data columns (total 49 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   STORE_KEY                         563113 non-null  int32
#  1   STORE_NUMBER                      563113 non-null  int16
#  2   STORE_NAME                        563113 non-null  object
#  3   STORE_TYPE_NAME                   563113 non-null  category
#  4   OPEN_DATE                         563113 non-null  datetime64[ns]
#  5   CLOSE_DATE                        563113 non-null  datetime64[ns]
#  6   MONTH_NAME                        563113 non-null  object
#  7   DAY_NAME                          563113 non-null  object
#  8   BUSINESS_DATE                     563113 non-null  datetime64[ns]
#  9   CITY_NAME                         563113 non-null  category
#  10  STATE_CODE                        563113 non-null  category
# ...

# %%
df['SEASON']
# Out:
# 0         Autumn
# 1         Spring
# 2         Winter
# 3         Autumn
# 4         Autumn
#            ...
# 563108    Spring
# 563109    Winter
# 563110    Winter
# 563111    Spring
# 563112    Spring
# Name: SEASON, Length: 563113, dtype: object

# %%
month_name_index = 7
day_name_index = 8
month_name = df['BUSINESS_DATE'].dt.month_name()
day_name = df['BUSINESS_DATE'].dt.day_name()
df.insert(loc = month_name_index, column = 'MONTH_NAME', value = month_name)
df.insert(loc = day_name_index, column = 'DAY_NAME', value = day_name)
df
# Out:
#         STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE  \
# 0             825             2        TX2       FRANCHISE 1998-05-09
# 1             825             2        TX2       FRANCHISE 1998-05-09
# 2             825             2        TX2       FRANCHISE 1998-05-09
# 3             825             2        TX2       FRANCHISE 1998-05-09
# 4             825             2        TX2       FRANCHISE 1998-05-09
# ...           ...           ...        ...             ...        ...
# 563108        791          7005     OH7005       FRANCHISE 2020-10-12
# 563109        791          7005     OH7005       FRANCHISE 2020-10-12
# 563110        791          7005     OH7005       FRANCHISE 2020-10-12
# 563111        791          7005     OH7005       FRANCHISE 2020-10-12
# 563112        791          7005     OH7005       FRANCHISE 2020-10-12
#
#        CLOSE_DATE BUSINESS_DATE MONTH_NAME   DAY_NAME SEASON_NAME CITY_NAME  \
# ...

# %%
df
# Out:
#         STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE  \
# 0             825             2        TX2       FRANCHISE 1998-05-09
# 1             825             2        TX2       FRANCHISE 1998-05-09
# 2             825             2        TX2       FRANCHISE 1998-05-09
# 3             825             2        TX2       FRANCHISE 1998-05-09
# 4             825             2        TX2       FRANCHISE 1998-05-09
# ...           ...           ...        ...             ...        ...
# 563108        791          7005     OH7005       FRANCHISE 2020-10-12
# 563109        791          7005     OH7005       FRANCHISE 2020-10-12
# 563110        791          7005     OH7005       FRANCHISE 2020-10-12
# 563111        791          7005     OH7005       FRANCHISE 2020-10-12
# 563112        791          7005     OH7005       FRANCHISE 2020-10-12
#
#        CLOSE_DATE MONTH_NAME   DAY_NAME BUSINESS_DATE CITY_NAME STATE_CODE  \
# ...

# %%
season_name_index = 9
df.insert(loc = season_name_index, column = 'SEASON_NAME', value = df['SEASON'])

# %%
df.drop(columns = {'MONTH_NAME', 'DAY_NAME'},inplace = True)

# %%
df.insert(loc = 10, column = 'YEAR', value = df['BUSINESS_DATE'].dt.year)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27568\1518842973.py in ?()
# ----> 1 df.insert(loc = 10, column = 'YEAR', value = df['BUSINESS_DATE'].dt.year)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    4927                 "'self.flags.allows_duplicate_labels' is False."
#    4928             )
#    4929         if not allow_duplicates and column in self.columns:
#    4930             # Should this be a different kind of error??
# -> 4931             raise ValueError(f"cannot insert {column}, already exists")
#    4932         if not is_integer(loc):
#    4933             raise TypeError("loc must be int")
#    4934         # convert non stdlib ints to satisfy typing checks
#
# ValueError: cannot insert YEAR, already exists

# %%
df.head(1)
# Out:
#    STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 0        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#   BUSINESS_DATE MONTH_NAME  DAY_NAME SEASON_NAME  YEAR CITY_NAME STATE_CODE  \
# 0    2022-11-17   November  Thursday      Autumn  2022    IRVING         TX
#
#   STATE_NAME TIME_ZONE_NAME  DMA_ID          DMA_NAME STORE_STATUS  REGION_ID  \
# 0      TEXAS        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE          1
#
#   REGION_NAME  PRIOR_STORE_NUMBER STORE_LIVE_DATE STORE_FUNCTIONAL_STATUS  \
# 0   SOUTHWEST                   0      1998-05-09             OPERATIONAL
#
#   GLOBAL_REGION_NAME GLOBAL_REGION_STORE_TYPE_NAME       AREA_REGION  \
# 0           Domestic             DOMESTICFRANCHISE  DALLAS-FT. WORTH
#
#   DISPATCH_GO_LIVE_DATE DOOR_DASH_GO_LIVE_DATE DOOR_DASH_MARKUP_GO_LIVE_DATE  \
# 0            2019-04-17             2019-04-17                    2020-09-27
#
# ...

# %%
df['NET_SALES_FINAL_USD_AMOUNT'].rolling(7).mean()
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#              ...
# 563108    1505.285714
# 563109    1578.000000
# 563110    1671.428571
# 563111    1648.000000
# 563112    1738.000000
# Name: NET_SALES_FINAL_USD_AMOUNT, Length: 563113, dtype: float64

# %%
df.insert( loc = 39, column = 'PER_TRANSACTION_SALES', value = df['NET_SALES_FINAL_USD_AMOUNT']/df['TRANSACTION_FINAL_COUNT'])

# %%
df.insert( loc = 42, column = 'PY_PER_TRANSACTION_SALES', value = df['PY_NET_SALES_FINAL_USD_AMOUNT']/df['PY_TRANSACTION_FINAL_COUNT'])

# %%
df.head(2)
# Out:
#    STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 0        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 1        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#   BUSINESS_DATE MONTH_NAME  DAY_NAME SEASON_NAME  YEAR CITY_NAME STATE_CODE  \
# 0    2022-11-17   November  Thursday      Autumn  2022    IRVING         TX
# 1    2023-05-26        May    Friday      Spring  2023    IRVING         TX
#
#   STATE_NAME TIME_ZONE_NAME  DMA_ID          DMA_NAME STORE_STATUS  REGION_ID  \
# 0      TEXAS        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE          1
# 1      TEXAS        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE          1
#
#   REGION_NAME  PRIOR_STORE_NUMBER STORE_LIVE_DATE STORE_FUNCTIONAL_STATUS  \
# 0   SOUTHWEST                   0      1998-05-09             OPERATIONAL
# 1   SOUTHWEST                   0      1998-05-09             OPERATIONAL
#
# ...

# %%
df.insert( loc = 40, column = 'ROLLING_TRANSACTION_LAST_7_DAYS', value = df['TRANSACTION_FINAL_COUNT'].rolling(7).mean().fillna(method='bfill'))
# Out:
# C:\Users\yashd\AppData\Local\Temp\ipykernel_38904\1871638506.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.insert( loc = 40, column = 'ROLLING_TRANSACTION_LAST_7_DAYS', value = df['TRANSACTION_FINAL_COUNT'].rolling(7).mean().fillna(method='bfill'))

# %%
df.head(5)
# Out:
#    STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 0        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 1        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 2        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 3        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 4        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#   BUSINESS_DATE MONTH_NAME   DAY_NAME SEASON_NAME  YEAR CITY_NAME STATE_CODE  \
# 0    2022-11-17   November   Thursday      Autumn  2022    IRVING         TX
# 1    2023-05-26        May     Friday      Spring  2023    IRVING         TX
# 2    2022-12-16   December     Friday      Winter  2022    IRVING         TX
# 3    2023-09-18  September     Monday      Autumn  2023    IRVING         TX
# 4    2022-11-02   November  Wednesday      Autumn  2022    IRVING         TX
#
# ...

# %%
df1 = df.copy()

# %%
df.to_csv('heheheh.csv')

# %%
df['STORE_NUMBER'].unique()
# Out:
# array([   2,    5,    7,   16,   27,   31,   39,   51,   52,   61,   62,
#          64,   72,   78,   94,  101,  107,  109,  123,  127,  133,  137,
#         144,  150,  153,  155,  158,  167,  171,  182,  202,  205,  207,
#         219,  234,  237,  238,  245,  249,  250,  251,  254,  257,  261,
#         271,  287,  295,  296,  298,  302,  308,  315,  320,  323,  340,
#         345,  353,  361,  363,  372,  373,  376,  380,  386,  387,  389,
#         391,  392,  407,  411,  424,  431,  435,  441,  442,  443,  453,
#         458,  465,  469,  484,  488,  494,  500,  509,  511,  514,  516,
#         526,  534,  537,  538,  545,  551,  552,  573,  576,  577,  578,
#         580,  584,  587,  589,  598,  600,  601,  605,  610,  611,  622,
#         625,  632,  633,  637,  656,  671,  672,  676,  679,  684,  686,
#         687,  692,  700,  708,  712,  713,  725,  727,  734,  737,  743,
#         748,  751,  754,  759,  766,  769,  770,  771,  775,  777,  781,
# ...

# %%
index = 40
df.insert(index, 'ROLLING_WINDOW_OF_7_DAYS', '')

# %%
df.head(3)
# Out:
#    STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 0        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 1        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 2        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#   BUSINESS_DATE MONTH_NAME  DAY_NAME SEASON_NAME  YEAR CITY_NAME STATE_CODE  \
# 0    2022-11-17   November  Thursday      Autumn  2022    IRVING         TX
# 1    2023-05-26        May    Friday      Spring  2023    IRVING         TX
# 2    2022-12-16   December    Friday      Winter  2022    IRVING         TX
#
#   STATE_NAME TIME_ZONE_NAME  DMA_ID          DMA_NAME STORE_STATUS  REGION_ID  \
# 0      TEXAS        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE          1
# 1      TEXAS        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE          1
# 2      TEXAS        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE          1
#
# ...

# %%
df[df['STORE_NUMBER'] == 2]['NET_SALES_FINAL_USD_AMOUNT'].rolling(3).mean()
# Out:
# 0               NaN
# 1               NaN
# 2       3458.666667
# 3       3258.666667
# 4       2460.000000
#            ...
# 1709    3070.333333
# 1710    2790.333333
# 1711    2122.333333
# 1712    1976.666667
# 1713    1805.000000
# Name: NET_SALES_FINAL_USD_AMOUNT, Length: 1714, dtype: float64

# %%
holiday_index = 7
df.insert( holiday_index, 'IS_A_HOLIDAY', '')

# %%
df.head(10)
# Out:
#    STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 0        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 1        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 2        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 3        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 4        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 5        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 6        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 7        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 8        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 9        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#   BUSINESS_DATE IS_A_HOLIDAY MONTH_NAME   DAY_NAME SEASON_NAME  YEAR  \
# ...

# %%
df.loc[df['BUSINESS_DATE'].isin(all_holidays_and_events), 'IS_A_HOLIDAY'] = 1
df.loc[~df['BUSINESS_DATE'].isin(all_holidays_and_events), 'IS_A_HOLIDAY'] = 0

# %%
df.head(2)
# Out:
#    STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 0        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 1        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#   BUSINESS_DATE IS_A_HOLIDAY MONTH_NAME  DAY_NAME SEASON_NAME  YEAR CITY_NAME  \
# 0    2022-11-17            0   November  Thursday      Autumn  2022    IRVING
# 1    2023-05-26            0        May    Friday      Spring  2023    IRVING
#
#   STATE_CODE STATE_NAME TIME_ZONE_NAME  DMA_ID          DMA_NAME STORE_STATUS  \
# 0         TX      TEXAS        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE
# 1         TX      TEXAS        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE
#
#    REGION_ID REGION_NAME  PRIOR_STORE_NUMBER STORE_LIVE_DATE  \
# 0          1   SOUTHWEST                   0      1998-05-09
# 1          1   SOUTHWEST                   0      1998-05-09
#
# ...

# %%
df.drop(columns = {'IS_HOLIDAY', 'SEASON'},inplace = True)

# %%
df['ROLLING_WINDOW_OF_7_DAYS'] = df.groupby('STORE_NUMBER')['NET_SALES_FINAL_USD_AMOUNT'].transform(lambda x: x.rolling(window = 7, min_periods = 1).mean())

# %%
df.head(1)
# Out:
#    STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 0        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#   BUSINESS_DATE IS_A_HOLIDAY MONTH_NAME  DAY_NAME SEASON_NAME  YEAR CITY_NAME  \
# 0    2022-11-17            0   November  Thursday      Autumn  2022    IRVING
#
#   STATE_CODE STATE_NAME TIME_ZONE_NAME  DMA_ID          DMA_NAME STORE_STATUS  \
# 0         TX      TEXAS        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE
#
#    REGION_ID REGION_NAME  PRIOR_STORE_NUMBER STORE_LIVE_DATE  \
# 0          1   SOUTHWEST                   0      1998-05-09
#
#   STORE_FUNCTIONAL_STATUS GLOBAL_REGION_NAME GLOBAL_REGION_STORE_TYPE_NAME  \
# 0             OPERATIONAL           Domestic             DOMESTICFRANCHISE
#
#         AREA_REGION DISPATCH_GO_LIVE_DATE DOOR_DASH_GO_LIVE_DATE  \
# 0  DALLAS-FT. WORTH            2019-04-17             2019-04-17
#
#   DOOR_DASH_MARKUP_GO_LIVE_DATE STORE_CONCEPT_NAME UBER_EATS_MARKUP_DATE  \
# ...

# %%
df.drop(columns = {'ROLLING_WINDOW_OF_14_DAYS'},inplace = True)

# %%
df['ROLLING_WINDOW_OF_14_DAYS'] = df.groupby('STORE_NUMBER')['NET_SALES_FINAL_USD_AMOUNT'].transform(lambda x: x.rolling(window = 14, min_periods = 1).mean())

# %%
index = 42
df.insert(index, 'ROLLING_WINDOW_OF_14_DAYS', '')

# %%
index = 43
df.insert(index, 'ROLLING_WINDOW_OF_30_DAYS', '')

# %%
index = 44
df.insert(index, 'ROLLING_WINDOW_OF_90_DAYS', '')

# %%
index = 45
df.insert(index, 'ROLLING_WINDOW_OF_180_DAYS', '')

# %%
index = 46
df.insert(index, 'ROLLING_WINDOW_OF_365_DAYS', '')

# %%
df.head(1)
# Out:
#    STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 0        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#   BUSINESS_DATE IS_A_HOLIDAY MONTH_NAME  DAY_NAME SEASON_NAME  YEAR CITY_NAME  \
# 0    2022-11-17            0   November  Thursday      Autumn  2022    IRVING
#
#   STATE_CODE STATE_NAME TIME_ZONE_NAME  DMA_ID          DMA_NAME STORE_STATUS  \
# 0         TX      TEXAS        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE
#
#    REGION_ID REGION_NAME  PRIOR_STORE_NUMBER STORE_LIVE_DATE  \
# 0          1   SOUTHWEST                   0      1998-05-09
#
#   STORE_FUNCTIONAL_STATUS GLOBAL_REGION_NAME GLOBAL_REGION_STORE_TYPE_NAME  \
# 0             OPERATIONAL           Domestic             DOMESTICFRANCHISE
#
#         AREA_REGION DISPATCH_GO_LIVE_DATE DOOR_DASH_GO_LIVE_DATE  \
# 0  DALLAS-FT. WORTH            2019-04-17             2019-04-17
#
#   DOOR_DASH_MARKUP_GO_LIVE_DATE STORE_CONCEPT_NAME UBER_EATS_MARKUP_DATE  \
# ...

# %%
index = 44
df.insert(index, 'ROLLING_WINDOW_OF_60_DAYS', '')

# %%
df['ROLLING_WINDOW_OF_14_DAYS'] = df.groupby('STORE_NUMBER')['NET_SALES_FINAL_USD_AMOUNT'].transform(lambda x: x.rolling(window = 14, min_periods = 1).mean())
df['ROLLING_WINDOW_OF_30_DAYS'] = df.groupby('STORE_NUMBER')['NET_SALES_FINAL_USD_AMOUNT'].transform(lambda x: x.rolling(window = 30, min_periods = 1).mean())
df['ROLLING_WINDOW_OF_60_DAYS'] = df.groupby('STORE_NUMBER')['NET_SALES_FINAL_USD_AMOUNT'].transform(lambda x: x.rolling(window = 60, min_periods = 1).mean())
df['ROLLING_WINDOW_OF_90_DAYS'] = df.groupby('STORE_NUMBER')['NET_SALES_FINAL_USD_AMOUNT'].transform(lambda x: x.rolling(window = 90, min_periods = 1).mean())
df['ROLLING_WINDOW_OF_180_DAYS'] = df.groupby('STORE_NUMBER')['NET_SALES_FINAL_USD_AMOUNT'].transform(lambda x: x.rolling(window = 180, min_periods = 1).mean())
df['ROLLING_WINDOW_OF_365_DAYS'] = df.groupby('STORE_NUMBER')['NET_SALES_FINAL_USD_AMOUNT'].transform(lambda x: x.rolling(window = 365, min_periods = 1).mean())

# %%
df.head(1)
# Out:
#    STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 0        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#   BUSINESS_DATE IS_A_HOLIDAY MONTH_NAME  DAY_NAME SEASON_NAME  YEAR CITY_NAME  \
# 0    2022-11-17            0   November  Thursday      Autumn  2022    IRVING
#
#   STATE_CODE STATE_NAME TIME_ZONE_NAME  DMA_ID          DMA_NAME STORE_STATUS  \
# 0         TX      TEXAS        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE
#
#    REGION_ID REGION_NAME  PRIOR_STORE_NUMBER STORE_LIVE_DATE  \
# 0          1   SOUTHWEST                   0      1998-05-09
#
#   STORE_FUNCTIONAL_STATUS GLOBAL_REGION_NAME GLOBAL_REGION_STORE_TYPE_NAME  \
# 0             OPERATIONAL           Domestic             DOMESTICFRANCHISE
#
#         AREA_REGION DISPATCH_GO_LIVE_DATE DOOR_DASH_GO_LIVE_DATE  \
# 0  DALLAS-FT. WORTH            2019-04-17             2019-04-17
#
#   DOOR_DASH_MARKUP_GO_LIVE_DATE STORE_CONCEPT_NAME UBER_EATS_MARKUP_DATE  \
# ...

# %%
index = 48
df.insert(index, 'TRANSACTION_COUNT_ROLLING_WINDOW_7_DAYS', '')

# %%
index = 48
df.insert(index, 'TRANSACTION_COUNT_ROLLING_WINDOW_14_DAYS', '')
index = 49
df.insert(index, 'TRANSACTION_COUNT_ROLLING_WINDOW_30_DAYS', '')
index = 50
df.insert(index, 'TRANSACTION_COUNT_ROLLING_WINDOW_60_DAYS', '')
index = 51
df.insert(index, 'TRANSACTION_COUNT_ROLLING_WINDOW_90_DAYS', '')
index = 52
df.insert(index, 'TRANSACTION_COUNT_ROLLING_WINDOW_180_DAYS', '')
index = 53
df.insert(index, 'TRANSACTION_COUNT_ROLLING_WINDOW_365_DAYS', '')

# %%
df.head(1)
# Out:
#    STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 0        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#   BUSINESS_DATE IS_A_HOLIDAY MONTH_NAME  DAY_NAME SEASON_NAME  YEAR CITY_NAME  \
# 0    2022-11-17            0   November  Thursday      Autumn  2022    IRVING
#
#   STATE_CODE STATE_NAME TIME_ZONE_NAME  DMA_ID          DMA_NAME STORE_STATUS  \
# 0         TX      TEXAS        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE
#
#    REGION_ID REGION_NAME  PRIOR_STORE_NUMBER STORE_LIVE_DATE  \
# 0          1   SOUTHWEST                   0      1998-05-09
#
#   STORE_FUNCTIONAL_STATUS GLOBAL_REGION_NAME GLOBAL_REGION_STORE_TYPE_NAME  \
# 0             OPERATIONAL           Domestic             DOMESTICFRANCHISE
#
#         AREA_REGION DISPATCH_GO_LIVE_DATE DOOR_DASH_GO_LIVE_DATE  \
# 0  DALLAS-FT. WORTH            2019-04-17             2019-04-17
#
#   DOOR_DASH_MARKUP_GO_LIVE_DATE STORE_CONCEPT_NAME UBER_EATS_MARKUP_DATE  \
# ...

# %%
df['TRANSACTION_COUNT_ROLLING_WINDOW_7_DAYS'] = df.groupby('STORE_NUMBER')['TRANSACTION_FINAL_COUNT'].transform(lambda x: x.rolling(window = 7, min_periods = 1).mean())
df['TRANSACTION_COUNT_ROLLING_WINDOW_14_DAYS'] = df.groupby('STORE_NUMBER')['TRANSACTION_FINAL_COUNT'].transform(lambda x: x.rolling(window = 14, min_periods = 1).mean())
df['TRANSACTION_COUNT_ROLLING_WINDOW_30_DAYS'] = df.groupby('STORE_NUMBER')['TRANSACTION_FINAL_COUNT'].transform(lambda x: x.rolling(window = 30, min_periods = 1).mean())
df['TRANSACTION_COUNT_ROLLING_WINDOW_60_DAYS'] = df.groupby('STORE_NUMBER')['TRANSACTION_FINAL_COUNT'].transform(lambda x: x.rolling(window = 60, min_periods = 1).mean())
df['TRANSACTION_COUNT_ROLLING_WINDOW_90_DAYS'] = df.groupby('STORE_NUMBER')['TRANSACTION_FINAL_COUNT'].transform(lambda x: x.rolling(window = 90, min_periods = 1).mean())
df['TRANSACTION_COUNT_ROLLING_WINDOW_180_DAYS'] = df.groupby('STORE_NUMBER')['TRANSACTION_FINAL_COUNT'].transform(lambda x: x.rolling(window = 180, min_periods = 1).mean())
df['TRANSACTION_COUNT_ROLLING_WINDOW_365_DAYS'] = df.groupby('STORE_NUMBER')['TRANSACTION_FINAL_COUNT'].transform(lambda x: x.rolling(window = 365, min_periods = 1).mean())

# %%
df.head(1)
# Out:
#    STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 0        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#   BUSINESS_DATE IS_A_HOLIDAY MONTH_NAME  DAY_NAME SEASON_NAME  YEAR CITY_NAME  \
# 0    2022-11-17            0   November  Thursday      Autumn  2022    IRVING
#
#   STATE_CODE STATE_NAME TIME_ZONE_NAME  DMA_ID          DMA_NAME STORE_STATUS  \
# 0         TX      TEXAS        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE
#
#    REGION_ID REGION_NAME  PRIOR_STORE_NUMBER STORE_LIVE_DATE  \
# 0          1   SOUTHWEST                   0      1998-05-09
#
#   STORE_FUNCTIONAL_STATUS GLOBAL_REGION_NAME GLOBAL_REGION_STORE_TYPE_NAME  \
# 0             OPERATIONAL           Domestic             DOMESTICFRANCHISE
#
#         AREA_REGION DISPATCH_GO_LIVE_DATE DOOR_DASH_GO_LIVE_DATE  \
# 0  DALLAS-FT. WORTH            2019-04-17             2019-04-17
#
#   DOOR_DASH_MARKUP_GO_LIVE_DATE STORE_CONCEPT_NAME UBER_EATS_MARKUP_DATE  \
# ...

# %%
index = 54
df.insert(index, 'PER_TRANSACTION_SALES_ROLLING_WINDOW_7_DAYS', '')

# %%
index = 55
df.insert(index, 'PER_TRANSACTION_SALES_ROLLING_WINDOW_14_DAYS', '')
index = 56
df.insert(index, 'PER_TRANSACTION_SALES_ROLLING_WINDOW_30_DAYS', '')
index = 57
df.insert(index, 'PER_TRANSACTION_SALES_ROLLING_WINDOW_60_DAYS', '')
index = 58
df.insert(index, 'PER_TRANSACTION_SALES_ROLLING_WINDOW_90_DAYS', '')
index = 59
df.insert(index, 'PER_TRANSACTION_SALES_ROLLING_WINDOW_180_DAYS', '')
index = 60
df.insert(index, 'PER_TRANSACTION_SALES_ROLLING_WINDOW_365_DAYS', '')

# %%
df.head(1)
# Out:
#    STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 0        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#   BUSINESS_DATE IS_A_HOLIDAY MONTH_NAME  DAY_NAME SEASON_NAME  YEAR CITY_NAME  \
# 0    2022-11-17            0   November  Thursday      Autumn  2022    IRVING
#
#   STATE_CODE STATE_NAME TIME_ZONE_NAME  DMA_ID          DMA_NAME STORE_STATUS  \
# 0         TX      TEXAS        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE
#
#    REGION_ID REGION_NAME  PRIOR_STORE_NUMBER STORE_LIVE_DATE  \
# 0          1   SOUTHWEST                   0      1998-05-09
#
#   STORE_FUNCTIONAL_STATUS GLOBAL_REGION_NAME GLOBAL_REGION_STORE_TYPE_NAME  \
# 0             OPERATIONAL           Domestic             DOMESTICFRANCHISE
#
#         AREA_REGION DISPATCH_GO_LIVE_DATE DOOR_DASH_GO_LIVE_DATE  \
# 0  DALLAS-FT. WORTH            2019-04-17             2019-04-17
#
#   DOOR_DASH_MARKUP_GO_LIVE_DATE STORE_CONCEPT_NAME UBER_EATS_MARKUP_DATE  \
# ...

# %%
df['PER_TRANSACTION_SALES_ROLLING_WINDOW_7_DAYS'] = df.groupby('STORE_NUMBER')['PER_TRANSACTION_SALES'].transform(lambda x: x.rolling(window = 7, min_periods = 1).mean())
df['PER_TRANSACTION_SALES_ROLLING_WINDOW_14_DAYS'] = df.groupby('STORE_NUMBER')['PER_TRANSACTION_SALES'].transform(lambda x: x.rolling(window = 14, min_periods = 1).mean())
df['PER_TRANSACTION_SALES_ROLLING_WINDOW_30_DAYS'] = df.groupby('STORE_NUMBER')['PER_TRANSACTION_SALES'].transform(lambda x: x.rolling(window = 30, min_periods = 1).mean())
df['PER_TRANSACTION_SALES_ROLLING_WINDOW_60_DAYS'] = df.groupby('STORE_NUMBER')['PER_TRANSACTION_SALES'].transform(lambda x: x.rolling(window = 60, min_periods = 1).mean())
df['PER_TRANSACTION_SALES_ROLLING_WINDOW_90_DAYS'] = df.groupby('STORE_NUMBER')['PER_TRANSACTION_SALES'].transform(lambda x: x.rolling(window = 90, min_periods = 1).mean())
df['PER_TRANSACTION_SALES_ROLLING_WINDOW_180_DAYS'] = df.groupby('STORE_NUMBER')['PER_TRANSACTION_SALES'].transform(lambda x: x.rolling(window = 180, min_periods = 1).mean())
df['PER_TRANSACTION_SALES_ROLLING_WINDOW_365_DAYS'] = df.groupby('STORE_NUMBER')['PER_TRANSACTION_SALES'].transform(lambda x: x.rolling(window = 365, min_periods = 1).mean())

# %%
df.head(10)
# Out:
#    STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 0        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 1        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 2        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 3        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 4        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 5        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 6        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 7        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 8        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
# 9        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#   BUSINESS_DATE IS_A_HOLIDAY MONTH_NAME   DAY_NAME SEASON_NAME  YEAR  \
# ...

# %%
df.sort_values(['STORE_NUMBER','BUSINESS_DATE'], inplace = True)

# %%
index = 65
df.insert(index, 'SALES_ROLLING_WINDOW_7_DAYS', '')

# %%
df.head(1)
# Out:
#      STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 710        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#     BUSINESS_DATE IS_A_HOLIDAY MONTH_NAME DAY_NAME SEASON_NAME  YEAR  \
# 710    2019-04-23            0      April  Tuesday      Spring  2019
#
#     CITY_NAME STATE_CODE STATE_NAME TIME_ZONE_NAME  DMA_ID          DMA_NAME  \
# 710    IRVING         TX      TEXAS        CENTRAL     623  DALLAS-FT. WORTH
#
#     STORE_STATUS  REGION_ID REGION_NAME  PRIOR_STORE_NUMBER STORE_LIVE_DATE  \
# 710       ACTIVE          1   SOUTHWEST                   0      1998-05-09
#
#     STORE_FUNCTIONAL_STATUS GLOBAL_REGION_NAME GLOBAL_REGION_STORE_TYPE_NAME  \
# 710             OPERATIONAL           Domestic             DOMESTICFRANCHISE
#
#           AREA_REGION DISPATCH_GO_LIVE_DATE DOOR_DASH_GO_LIVE_DATE  \
# 710  DALLAS-FT. WORTH            2019-04-17             2019-04-17
#
# ...

# %%
index = 66
df.insert(index, 'PY_SALES_ROLLING_WINDOW_14_DAYS', '')
index = 67
df.insert(index, 'PY_SALES_ROLLING_WINDOW_30_DAYS', '')
index = 68
df.insert(index, 'PY_SALES_ROLLING_WINDOW_60_DAYS', '')
index = 69
df.insert(index, 'PY_SALES_ROLLING_WINDOW_90_DAYS', '')
index = 70
df.insert(index, 'PY_SALES_ROLLING_WINDOW_180_DAYS', '')
index = 71
df.insert(index, 'PY_SALES_ROLLING_WINDOW_365_DAYS', '')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27568\3306077170.py in ?()
#       1 index = 66
# ----> 2 df.insert(index, 'PY_SALES_ROLLING_WINDOW_14_DAYS', '')
#       3 index = 67
#       4 df.insert(index, 'PY_SALES_ROLLING_WINDOW_30_DAYS', '')
#       5 index = 68
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    4927                 "'self.flags.allows_duplicate_labels' is False."
#    4928             )
#    4929         if not allow_duplicates and column in self.columns:
#    4930             # Should this be a different kind of error??
# -> 4931             raise ValueError(f"cannot insert {column}, already exists")
#    4932         if not is_integer(loc):
#    4933             raise TypeError("loc must be int")
# ...

# %%
df.head(1)
# Out:
#      STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 710        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#     BUSINESS_DATE IS_A_HOLIDAY MONTH_NAME DAY_NAME SEASON_NAME  YEAR  \
# 710    2019-04-23            0      April  Tuesday      Spring  2019
#
#     CITY_NAME STATE_CODE STATE_NAME TIME_ZONE_NAME  DMA_ID          DMA_NAME  \
# 710    IRVING         TX      TEXAS        CENTRAL     623  DALLAS-FT. WORTH
#
#     STORE_STATUS  REGION_ID REGION_NAME  PRIOR_STORE_NUMBER STORE_LIVE_DATE  \
# 710       ACTIVE          1   SOUTHWEST                   0      1998-05-09
#
#     STORE_FUNCTIONAL_STATUS GLOBAL_REGION_NAME GLOBAL_REGION_STORE_TYPE_NAME  \
# 710             OPERATIONAL           Domestic             DOMESTICFRANCHISE
#
#           AREA_REGION DISPATCH_GO_LIVE_DATE DOOR_DASH_GO_LIVE_DATE  \
# 710  DALLAS-FT. WORTH            2019-04-17             2019-04-17
#
# ...

# %%
index = 75
df.insert(index, 'PY_TRANSACTION_COUNT_ROLLING_WINDOW_60_DAYS', '')
index = 76
df.insert(index, 'PY_TRANSACTION_COUNT_ROLLING_WINDOW_90_DAYS', '')
index = 77
df.insert(index, 'PY_TRANSACTION_COUNT_ROLLING_WINDOW_180_DAYS', '')
index = 78
df.insert(index, 'PY_TRANSACTION_COUNT_ROLLING_WINDOW_365_DAYS', '')
index = 79
df.insert(index, 'PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_7_DAYS', '')
index = 80
df.insert(index, 'PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_14_DAYS', '')
index = 81
df.insert(index, 'PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_30_DAYS', '')
index = 82
df.insert(index, 'PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_60_DAYS', '')
index = 83
df.insert(index, 'PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_90_DAYS', '')
index = 84
df.insert(index, 'PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_180_DAYS', '')
index = 85
df.insert(index, 'PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_365_DAYS', '')

# %%
df.head(1)
# Out:
#      STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 710        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#     BUSINESS_DATE IS_A_HOLIDAY MONTH_NAME DAY_NAME SEASON_NAME  YEAR  \
# 710    2019-04-23            0      April  Tuesday      Spring  2019
#
#     CITY_NAME STATE_CODE STATE_NAME TIME_ZONE_NAME  DMA_ID          DMA_NAME  \
# 710    IRVING         TX      TEXAS        CENTRAL     623  DALLAS-FT. WORTH
#
#     STORE_STATUS  REGION_ID REGION_NAME  PRIOR_STORE_NUMBER STORE_LIVE_DATE  \
# 710       ACTIVE          1   SOUTHWEST                   0      1998-05-09
#
#     STORE_FUNCTIONAL_STATUS GLOBAL_REGION_NAME GLOBAL_REGION_STORE_TYPE_NAME  \
# 710             OPERATIONAL           Domestic             DOMESTICFRANCHISE
#
#           AREA_REGION DISPATCH_GO_LIVE_DATE DOOR_DASH_GO_LIVE_DATE  \
# 710  DALLAS-FT. WORTH            2019-04-17             2019-04-17
#
# ...

# %%
df['PY_PER_TRANSACTION_SALES'] = df['PY_NET_SALES_FINAL_USD_AMOUNT'] / df['PY_TRANSACTION_FINAL_COUNT']

# %%
df['PY_PER_TRANSACTION_SALES'].fillna(0, inplace = True)

# %%
df['SALES_ROLLING_WINDOW_7_DAYS'] = df.groupby('STORE_NUMBER')['PY_NET_SALES_FINAL_USD_AMOUNT'].transform(lambda x: x.rolling(window = 7, min_periods = 1).mean())
df['PY_SALES_ROLLING_WINDOW_14_DAYS'] = df.groupby('STORE_NUMBER')['PY_NET_SALES_FINAL_USD_AMOUNT'].transform(lambda x: x.rolling(window = 14, min_periods = 1).mean())
df['PY_SALES_ROLLING_WINDOW_30_DAYS'] = df.groupby('STORE_NUMBER')['PY_NET_SALES_FINAL_USD_AMOUNT'].transform(lambda x: x.rolling(window = 30, min_periods = 1).mean())
df['PY_SALES_ROLLING_WINDOW_60_DAYS'] = df.groupby('STORE_NUMBER')['PY_NET_SALES_FINAL_USD_AMOUNT'].transform(lambda x: x.rolling(window = 60, min_periods = 1).mean())
df['PY_SALES_ROLLING_WINDOW_90_DAYS'] = df.groupby('STORE_NUMBER')['PY_NET_SALES_FINAL_USD_AMOUNT'].transform(lambda x: x.rolling(window = 90, min_periods = 1).mean())
df['PY_SALES_ROLLING_WINDOW_180_DAYS'] = df.groupby('STORE_NUMBER')['PY_NET_SALES_FINAL_USD_AMOUNT'].transform(lambda x: x.rolling(window = 180, min_periods = 1).mean())
df['PY_SALES_ROLLING_WINDOW_365_DAYS'] = df.groupby('STORE_NUMBER')['PY_NET_SALES_FINAL_USD_AMOUNT'].transform(lambda x: x.rolling(window = 365, min_periods = 1).mean())

# %%
df['PY_TRANSACTION_COUNT_ROLLING_WINDOW_7_DAYS'] = df.groupby('STORE_NUMBER')['PY_TRANSACTION_FINAL_COUNT'].transform(lambda x: x.rolling(window = 7, min_periods = 1).mean())
df['PY_TRANSACTION_COUNT_ROLLING_WINDOW_14_DAYS'] = df.groupby('STORE_NUMBER')['PY_TRANSACTION_FINAL_COUNT'].transform(lambda x: x.rolling(window = 14, min_periods = 1).mean())
df['PY_TRANSACTION_COUNT_ROLLING_WINDOW_30_DAYS'] = df.groupby('STORE_NUMBER')['PY_TRANSACTION_FINAL_COUNT'].transform(lambda x: x.rolling(window = 30, min_periods = 1).mean())
df['PY_TRANSACTION_COUNT_ROLLING_WINDOW_60_DAYS'] = df.groupby('STORE_NUMBER')['PY_TRANSACTION_FINAL_COUNT'].transform(lambda x: x.rolling(window = 60, min_periods = 1).mean())
df['PY_TRANSACTION_COUNT_ROLLING_WINDOW_90_DAYS'] = df.groupby('STORE_NUMBER')['PY_TRANSACTION_FINAL_COUNT'].transform(lambda x: x.rolling(window = 90, min_periods = 1).mean())
df['PY_TRANSACTION_COUNT_ROLLING_WINDOW_180_DAYS'] = df.groupby('STORE_NUMBER')['PY_TRANSACTION_FINAL_COUNT'].transform(lambda x: x.rolling(window = 180, min_periods = 1).mean())
df['PY_TRANSACTION_COUNT_ROLLING_WINDOW_365_DAYS'] = df.groupby('STORE_NUMBER')['PY_TRANSACTION_FINAL_COUNT'].transform(lambda x: x.rolling(window = 365, min_periods = 1).mean())

# %%
df['PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_7_DAYS'] = df.groupby('STORE_NUMBER')['PY_PER_TRANSACTION_SALES'].transform(lambda x: x.rolling(window = 7, min_periods = 1).mean())
df['PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_14_DAYS'] = df.groupby('STORE_NUMBER')['PY_PER_TRANSACTION_SALES'].transform(lambda x: x.rolling(window = 14, min_periods = 1).mean())
df['PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_30_DAYS'] = df.groupby('STORE_NUMBER')['PY_PER_TRANSACTION_SALES'].transform(lambda x: x.rolling(window = 30, min_periods = 1).mean())
df['PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_60_DAYS'] = df.groupby('STORE_NUMBER')['PY_PER_TRANSACTION_SALES'].transform(lambda x: x.rolling(window = 60, min_periods = 1).mean())
df['PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_90_DAYS'] = df.groupby('STORE_NUMBER')['PY_PER_TRANSACTION_SALES'].transform(lambda x: x.rolling(window = 90, min_periods = 1).mean())
df['PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_180_DAYS'] = df.groupby('STORE_NUMBER')['PY_PER_TRANSACTION_SALES'].transform(lambda x: x.rolling(window = 180, min_periods = 1).mean())
df['PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_365_DAYS'] = df.groupby('STORE_NUMBER')['PY_PER_TRANSACTION_SALES'].transform(lambda x: x.rolling(window = 365, min_periods = 1).mean())

# %%
df.head(1)
# Out:
#      STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 710        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#     BUSINESS_DATE IS_A_HOLIDAY MONTH_NAME DAY_NAME SEASON_NAME  YEAR  \
# 710    2019-04-23            0      April  Tuesday      Spring  2019
#
#     CITY_NAME STATE_CODE STATE_NAME TIME_ZONE_NAME  DMA_ID          DMA_NAME  \
# 710    IRVING         TX      TEXAS        CENTRAL     623  DALLAS-FT. WORTH
#
#     STORE_STATUS  REGION_ID REGION_NAME  PRIOR_STORE_NUMBER STORE_LIVE_DATE  \
# 710       ACTIVE          1   SOUTHWEST                   0      1998-05-09
#
#     STORE_FUNCTIONAL_STATUS GLOBAL_REGION_NAME GLOBAL_REGION_STORE_TYPE_NAME  \
# 710             OPERATIONAL           Domestic             DOMESTICFRANCHISE
#
#           AREA_REGION DISPATCH_GO_LIVE_DATE DOOR_DASH_GO_LIVE_DATE  \
# 710  DALLAS-FT. WORTH            2019-04-17             2019-04-17
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 563113 entries, 710 to 563087
# Data columns (total 94 columns):
#  #   Column                                            Non-Null Count   Dtype
# ---  ------                                            --------------   -----
#  0   STORE_KEY                                         563113 non-null  int32
#  1   STORE_NUMBER                                      563113 non-null  int16
#  2   STORE_NAME                                        563113 non-null  object
#  3   STORE_TYPE_NAME                                   563113 non-null  category
#  4   OPEN_DATE                                         563113 non-null  datetime64[ns]
#  5   CLOSE_DATE                                        563113 non-null  datetime64[ns]
#  6   BUSINESS_DATE                                     563113 non-null  datetime64[ns]
#  7   IS_A_HOLIDAY                                      563113 non-null  object
# ...

# %%
columns = ['ROLLING_WINDOW_OF_7_DAYS','ROLLING_WINDOW_OF_14_DAYS','ROLLING_WINDOW_OF_30_DAYS','ROLLING_WINDOW_OF_60_DAYS',
          'ROLLING_WINDOW_OF_90_DAYS','ROLLING_WINDOW_OF_180_DAYS','ROLLING_WINDOW_OF_365_DAYS','TRANSACTION_COUNT_ROLLING_WINDOW_7_DAYS',
          'TRANSACTION_COUNT_ROLLING_WINDOW_14_DAYS', 'TRANSACTION_COUNT_ROLLING_WINDOW_30_DAYS', 'TRANSACTION_COUNT_ROLLING_WINDOW_60_DAYS',
          'TRANSACTION_COUNT_ROLLING_WINDOW_180_DAYS', 'TRANSACTION_COUNT_ROLLING_WINDOW_365_DAYS','SALES_ROLLING_WINDOW_7_DAYS',
          'PY_SALES_ROLLING_WINDOW_14_DAYS', 'PY_SALES_ROLLING_WINDOW_30_DAYS', 'PY_SALES_ROLLING_WINDOW_60_DAYS', 'PY_SALES_ROLLING_WINDOW_90_DAYS',
          'PY_SALES_ROLLING_WINDOW_180_DAYS', 'PY_SALES_ROLLING_WINDOW_365_DAYS','PY_TRANSACTION_COUNT_ROLLING_WINDOW_7_DAYS', 
          'PY_TRANSACTION_COUNT_ROLLING_WINDOW_14_DAYS', 'PY_TRANSACTION_COUNT_ROLLING_WINDOW_30_DAYS', 'PY_TRANSACTION_COUNT_ROLLING_WINDOW_60_DAYS',
          'PY_TRANSACTION_COUNT_ROLLING_WINDOW_90_DAYS', 'PY_TRANSACTION_COUNT_ROLLING_WINDOW_180_DAYS' ,'PY_TRANSACTION_COUNT_ROLLING_WINDOW_365_DAYS']

# %%
for column in columns:
    df[column] = df[column].astype('int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 563113 entries, 710 to 563087
# Data columns (total 94 columns):
#  #   Column                                            Non-Null Count   Dtype
# ---  ------                                            --------------   -----
#  0   STORE_KEY                                         563113 non-null  int32
#  1   STORE_NUMBER                                      563113 non-null  int16
#  2   STORE_NAME                                        563113 non-null  object
#  3   STORE_TYPE_NAME                                   563113 non-null  category
#  4   OPEN_DATE                                         563113 non-null  datetime64[ns]
#  5   CLOSE_DATE                                        563113 non-null  datetime64[ns]
#  6   BUSINESS_DATE                                     563113 non-null  datetime64[ns]
#  7   IS_A_HOLIDAY                                      563113 non-null  object
# ...

# %%
df['IS_A_HOLIDAY'] = df['IS_A_HOLIDAY'].astype('int8')

# %%
df['MONTH_NAME'] = df['MONTH_NAME'].astype('category')
df['DAY_NAME'] = df['DAY_NAME'].astype('category')
df['SEASON_NAME'] = df['SEASON_NAME'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 563113 entries, 710 to 563087
# Data columns (total 94 columns):
#  #   Column                                            Non-Null Count   Dtype
# ---  ------                                            --------------   -----
#  0   STORE_KEY                                         563113 non-null  int32
#  1   STORE_NUMBER                                      563113 non-null  int16
#  2   STORE_NAME                                        563113 non-null  object
#  3   STORE_TYPE_NAME                                   563113 non-null  category
#  4   OPEN_DATE                                         563113 non-null  datetime64[ns]
#  5   CLOSE_DATE                                        563113 non-null  datetime64[ns]
#  6   BUSINESS_DATE                                     563113 non-null  datetime64[ns]
#  7   IS_A_HOLIDAY                                      563113 non-null  int8
# ...

# %%
column = ['PER_TRANSACTION_SALES', 'PER_TRANSACTION_SALES_ROLLING_WINDOW_7_DAYS', 'PER_TRANSACTION_SALES_ROLLING_WINDOW_14_DAYS',
          'PER_TRANSACTION_SALES_ROLLING_WINDOW_30_DAYS', 'PER_TRANSACTION_SALES_ROLLING_WINDOW_60_DAYS', 
          'PER_TRANSACTION_SALES_ROLLING_WINDOW_90_DAYS', 'PER_TRANSACTION_SALES_ROLLING_WINDOW_180_DAYS', 'PER_TRANSACTION_SALES_ROLLING_WINDOW_365_DAYS',
          'PY_PER_TRANSACTION_SALES', 'PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_7_DAYS' ,'PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_14_DAYS',
          'PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_30_DAYS', 'PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_60_DAYS', 'PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_90_DAYS',
          'PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_180_DAYS' , 'PY_PER_TRANSACTION_SALES_ROLLING_WINDOW_365_DAYS']
for col in column:
    df[column] = df[column].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 563113 entries, 710 to 563087
# Data columns (total 94 columns):
#  #   Column                                            Non-Null Count   Dtype
# ---  ------                                            --------------   -----
#  0   STORE_KEY                                         563113 non-null  int32
#  1   STORE_NUMBER                                      563113 non-null  int16
#  2   STORE_NAME                                        563113 non-null  object
#  3   STORE_TYPE_NAME                                   563113 non-null  category
#  4   OPEN_DATE                                         563113 non-null  datetime64[ns]
#  5   CLOSE_DATE                                        563113 non-null  datetime64[ns]
#  6   BUSINESS_DATE                                     563113 non-null  datetime64[ns]
#  7   IS_A_HOLIDAY                                      563113 non-null  int8
# ...

# %%
df['TRANSACTION_COUNT_ROLLING_WINDOW_90_DAYS'] = df['TRANSACTION_COUNT_ROLLING_WINDOW_90_DAYS'].astype('int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 563113 entries, 710 to 563087
# Data columns (total 94 columns):
#  #   Column                                            Non-Null Count   Dtype
# ---  ------                                            --------------   -----
#  0   STORE_KEY                                         563113 non-null  int32
#  1   STORE_NUMBER                                      563113 non-null  int16
#  2   STORE_NAME                                        563113 non-null  object
#  3   STORE_TYPE_NAME                                   563113 non-null  category
#  4   OPEN_DATE                                         563113 non-null  datetime64[ns]
#  5   CLOSE_DATE                                        563113 non-null  datetime64[ns]
#  6   BUSINESS_DATE                                     563113 non-null  datetime64[ns]
#  7   IS_A_HOLIDAY                                      563113 non-null  int8
# ...

# %%
df.to_csv('all_final.csv')
