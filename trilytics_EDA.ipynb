# %%
import pandas as pd

# %%
df = pd.read_csv('final_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563113 entries, 0 to 563112
# Data columns (total 46 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Unnamed: 0                        563113 non-null  int64
#  1   STORE_KEY                         563113 non-null  int64
#  2   STORE_NUMBER                      563113 non-null  int64
#  3   STORE_NAME                        563113 non-null  object
#  4   STORE_TYPE_NAME                   563113 non-null  object
#  5   OPEN_DATE                         563113 non-null  object
#  6   CLOSE_DATE                        563113 non-null  object
#  7   BUSINESS_DATE                     563113 non-null  object
#  8   CITY_NAME                         563113 non-null  object
#  9   STATE_CODE                        563113 non-null  object
#  10  STATE_NAME                        563113 non-null  object
# ...

# %%
df.drop(columns = {'Unnamed: 0'},inplace = True)

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#         STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME   OPEN_DATE  \
# 0             825             2        TX2       FRANCHISE  1998-05-09
# 1             825             2        TX2       FRANCHISE  1998-05-09
# 2             825             2        TX2       FRANCHISE  1998-05-09
# 3             825             2        TX2       FRANCHISE  1998-05-09
# 4             825             2        TX2       FRANCHISE  1998-05-09
# ...           ...           ...        ...             ...         ...
# 563108        791          7005     OH7005       FRANCHISE  2020-10-12
# 563109        791          7005     OH7005       FRANCHISE  2020-10-12
# 563110        791          7005     OH7005       FRANCHISE  2020-10-12
# 563111        791          7005     OH7005       FRANCHISE  2020-10-12
# 563112        791          7005     OH7005       FRANCHISE  2020-10-12
#
#         CLOSE_DATE BUSINESS_DATE CITY_NAME STATE_CODE STATE_NAME  \
# ...

# %%
df['STORE_NUMBER'].value_counts(ascending = True)
# Out:
# STORE_NUMBER
# 2463       3
# 2574       5
# 2348       9
# 2448      10
# 2435      10
#         ...
# 759     1714
# 754     1714
# 751     1714
# 788     1714
# 1206    1714
# Name: count, Length: 419, dtype: int64

# %%
df[df['STORE_NUMBER'] == 2435].sort_values('BUSINESS_DATE')
# Out:
#         STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME   OPEN_DATE  \
# 561400        741          2435     NV2435       FRANCHISE  2023-12-22
# 561396        741          2435     NV2435       FRANCHISE  2023-12-22
# 561395        741          2435     NV2435       FRANCHISE  2023-12-22
# 561397        741          2435     NV2435       FRANCHISE  2023-12-22
# 561398        741          2435     NV2435       FRANCHISE  2023-12-22
# 561402        741          2435     NV2435       FRANCHISE  2023-12-22
# 561403        741          2435     NV2435       FRANCHISE  2023-12-22
# 561399        741          2435     NV2435       FRANCHISE  2023-12-22
# 561404        741          2435     NV2435       FRANCHISE  2023-12-22
# 561401        741          2435     NV2435       FRANCHISE  2023-12-22
#
#         CLOSE_DATE BUSINESS_DATE        CITY_NAME STATE_CODE STATE_NAME  \
# 561400  1999-12-31    2023-12-22  NORTH LAS VEGAS         NV     NEVADA
# ...

# %%
df[df['CITY_NAME'] == 'NORTH LAS VEGAS']['STORE_NUMBER'].unique()
# Out:
# array([ 979, 2435])

# %%
# prompt: df[df['STORE_NUMBER'] == 2435].sort_values('BUSINESS_DATE') , plot the 'NET_SALES_FINAL_USD_AMOUNT vs date

import matplotlib.pyplot as plt
temp = df[df['STORE_NUMBER'] == 2435].sort_values('BUSINESS_DATE')
plt.plot(temp['BUSINESS_DATE'], temp['NET_SALES_FINAL_USD_AMOUNT'])
temp1 = df[df['STORE_NUMBER'] == 979].sort_values('BUSINESS_DATE', ascending = False).head(10).sort_values('BUSINESS_DATE')
plt.plot(temp1['BUSINESS_DATE'], temp1['NET_SALES_FINAL_USD_AMOUNT'])
plt.show()

# %%
df[df['STORE_NUMBER'] == 979].sort_values('BUSINESS_DATE' , ascending = False).head(10).sort_values('BUSINESS_DATE')
# Out:
#         STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME   OPEN_DATE  \
# 284047       1763           979      NV979       CORPORATE  2006-06-19
# 285414       1763           979      NV979       CORPORATE  2006-06-19
# 285416       1763           979      NV979       CORPORATE  2006-06-19
# 285028       1763           979      NV979       CORPORATE  2006-06-19
# 285410       1763           979      NV979       CORPORATE  2006-06-19
# 284815       1763           979      NV979       CORPORATE  2006-06-19
# 285017       1763           979      NV979       CORPORATE  2006-06-19
# 284241       1763           979      NV979       CORPORATE  2006-06-19
# 283845       1763           979      NV979       CORPORATE  2006-06-19
# 285037       1763           979      NV979       CORPORATE  2006-06-19
#
#         CLOSE_DATE BUSINESS_DATE        CITY_NAME STATE_CODE STATE_NAME  \
# 284047  1999-12-31    2023-12-22  NORTH LAS VEGAS         NV     NEVADA
# ...

# %%
df
# Out:
#         STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME   OPEN_DATE  \
# 0             825             2        TX2       FRANCHISE  1998-05-09
# 1             825             2        TX2       FRANCHISE  1998-05-09
# 2             825             2        TX2       FRANCHISE  1998-05-09
# 3             825             2        TX2       FRANCHISE  1998-05-09
# 4             825             2        TX2       FRANCHISE  1998-05-09
# ...           ...           ...        ...             ...         ...
# 563108        791          7005     OH7005       FRANCHISE  2020-10-12
# 563109        791          7005     OH7005       FRANCHISE  2020-10-12
# 563110        791          7005     OH7005       FRANCHISE  2020-10-12
# 563111        791          7005     OH7005       FRANCHISE  2020-10-12
# 563112        791          7005     OH7005       FRANCHISE  2020-10-12
#
#         CLOSE_DATE BUSINESS_DATE CITY_NAME STATE_CODE STATE_NAME  \
# ...

# %%
df['PROMOTION_OFFER'].unique()
# Out:
# array(['Overall Discount', 'Protein', 'Side', nan, 'Delivery', 'Dessert'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563113 entries, 0 to 563112
# Data columns (total 45 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   STORE_KEY                         563113 non-null  int64
#  1   STORE_NUMBER                      563113 non-null  int64
#  2   STORE_NAME                        563113 non-null  object
#  3   STORE_TYPE_NAME                   563113 non-null  object
#  4   OPEN_DATE                         563113 non-null  object
#  5   CLOSE_DATE                        563113 non-null  object
#  6   BUSINESS_DATE                     563113 non-null  object
#  7   CITY_NAME                         563113 non-null  object
#  8   STATE_CODE                        563113 non-null  object
#  9   STATE_NAME                        563113 non-null  object
#  10  TIME_ZONE_NAME                    563113 non-null  object
# ...

# %%
df[df['PROMOTION_OFFER'].isnull()]
# Out:
#         STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME   OPEN_DATE  \
# 4             825             2        TX2       FRANCHISE  1998-05-09
# 6             825             2        TX2       FRANCHISE  1998-05-09
# 7             825             2        TX2       FRANCHISE  1998-05-09
# 11            825             2        TX2       FRANCHISE  1998-05-09
# 16            825             2        TX2       FRANCHISE  1998-05-09
# ...           ...           ...        ...             ...         ...
# 563108        791          7005     OH7005       FRANCHISE  2020-10-12
# 563109        791          7005     OH7005       FRANCHISE  2020-10-12
# 563110        791          7005     OH7005       FRANCHISE  2020-10-12
# 563111        791          7005     OH7005       FRANCHISE  2020-10-12
# 563112        791          7005     OH7005       FRANCHISE  2020-10-12
#
#         CLOSE_DATE BUSINESS_DATE CITY_NAME STATE_CODE STATE_NAME  \
# ...

# %%
df.loc[ df[df['PROMOTION_OFFER'].isnull()].index , 'PROMOTION_OFFER'] = 'No Offers'

# %%
df.loc[ df[df['PROMOTION_ITEM'].isnull()].index , 'PROMOTION_ITEM'] = 'No Items'
df.loc[ df[df['PLATFORM'].isnull()].index , 'PLATFORM'] = 'No Platform'
df.loc[ df[df['FREQUENCY'].isnull()].index , 'FREQUENCY'] = 'None'
df.loc[ df[df['PROMOTION_COVERAGE'].isnull()].index , 'PROMOTION_COVERAGE'] = 'None'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563113 entries, 0 to 563112
# Data columns (total 45 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   STORE_KEY                         563113 non-null  int64
#  1   STORE_NUMBER                      563113 non-null  int64
#  2   STORE_NAME                        563113 non-null  object
#  3   STORE_TYPE_NAME                   563113 non-null  object
#  4   OPEN_DATE                         563113 non-null  object
#  5   CLOSE_DATE                        563113 non-null  object
#  6   BUSINESS_DATE                     563113 non-null  object
#  7   CITY_NAME                         563113 non-null  object
#  8   STATE_CODE                        563113 non-null  object
#  9   STATE_NAME                        563113 non-null  object
#  10  TIME_ZONE_NAME                    563113 non-null  object
# ...

# %%
dates = ['OPEN_DATE','CLOSE_DATE','BUSINESS_DATE','STORE_LIVE_DATE','DISPATCH_GO_LIVE_DATE','DOOR_DASH_GO_LIVE_DATE','DOOR_DASH_MARKUP_GO_LIVE_DATE','UBER_EATS_MARKUP_DATE']
for date in dates:
    df[date] = pd.to_datetime(df[date])

# %%
categorical_columns = ['STORE_TYPE_NAME' , 'CITY_NAME' , 'STATE_CODE' , 'STATE_NAME' , 'TIME_ZONE_NAME', 'DMA_NAME', 'STORE_STATUS', 'REGION_NAME', 'STORE_FUNCTIONAL_STATUS',
                       'GLOBAL_REGION_NAME', 'GLOBAL_REGION_STORE_TYPE_NAME', 'AREA_REGION', 'STORE_CONCEPT_NAME']
for i in categorical_columns:
  df[i] = df[i].astype('category')

# %%
df['STORE_KEY'] = df['STORE_KEY'].astype('int32')
df['STORE_NUMBER'] = df['STORE_NUMBER'].astype('int16')
df['DMA_ID'] = df['DMA_ID'].astype('int16')
df['REGION_ID'] = df['REGION_ID'].astype('int8')
df['TEMP_CLOSE_INDICATOR'] = df['TEMP_CLOSE_INDICATOR'].astype('int8')
df['PROJECTION_INCLUDED_INDICATOR'] = df['PROJECTION_INCLUDED_INDICATOR'].astype('int8')
df['BUSINESS_DATE_FISCAL_DAY_OF_YEAR'] = df['BUSINESS_DATE_FISCAL_DAY_OF_YEAR'].astype('int16')
df['BUSINESS_DATE_FISCAL_YEAR'] = df['BUSINESS_DATE_FISCAL_YEAR'].astype('int16')
df['COMP_BUSINESS_DATE_FISCAL_YEAR'] = df['COMP_BUSINESS_DATE_FISCAL_YEAR'].astype('int16')
df['COMPARABLE_INDICATOR'] = df['COMPARABLE_INDICATOR'].astype('int8')
df['TRANSACTION_FINAL_COUNT'] = df['TRANSACTION_FINAL_COUNT'].astype('int16')
df['NET_SALES_FINAL_USD_AMOUNT'] = df['NET_SALES_FINAL_USD_AMOUNT'].astype('int16')
df['PY_TRANSACTION_FINAL_COUNT'] = df['PY_TRANSACTION_FINAL_COUNT'].astype('int16')
df['PY_NET_SALES_FINAL_USD_AMOUNT'] = df['PY_NET_SALES_FINAL_USD_AMOUNT'].astype('int16')
df['PROMOTION_CASH_AMOUNT'] = df['PROMOTION_CASH_AMOUNT'].astype('int8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563113 entries, 0 to 563112
# Data columns (total 45 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   STORE_KEY                         563113 non-null  int32
#  1   STORE_NUMBER                      563113 non-null  int16
#  2   STORE_NAME                        563113 non-null  object
#  3   STORE_TYPE_NAME                   563113 non-null  category
#  4   OPEN_DATE                         563113 non-null  datetime64[ns]
#  5   CLOSE_DATE                        563113 non-null  datetime64[ns]
#  6   BUSINESS_DATE                     563113 non-null  datetime64[ns]
#  7   CITY_NAME                         563113 non-null  category
#  8   STATE_CODE                        563113 non-null  category
#  9   STATE_NAME                        563113 non-null  category
#  10  TIME_ZONE_NAME                    563113 non-null  category
# ...

# %%
categorical_columns1 = ['PROMOTION_TYPE', 'PROMOTION_OFFER', 'PROMOTION_ITEM', 'PLATFORM' , 'FREQUENCY', 'PROMOTION_COVERAGE']
for i in categorical_columns1:
  df[i] = df[i].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563113 entries, 0 to 563112
# Data columns (total 45 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   STORE_KEY                         563113 non-null  int32
#  1   STORE_NUMBER                      563113 non-null  int16
#  2   STORE_NAME                        563113 non-null  object
#  3   STORE_TYPE_NAME                   563113 non-null  category
#  4   OPEN_DATE                         563113 non-null  datetime64[ns]
#  5   CLOSE_DATE                        563113 non-null  datetime64[ns]
#  6   BUSINESS_DATE                     563113 non-null  datetime64[ns]
#  7   CITY_NAME                         563113 non-null  category
#  8   STATE_CODE                        563113 non-null  category
#  9   STATE_NAME                        563113 non-null  category
#  10  TIME_ZONE_NAME                    563113 non-null  category
# ...

# %%
df['PROMOTION_PERCENTAGE'] = pd.to_numeric(df['PROMOTION_PERCENTAGE'], downcast='float')

# %%
df['PRIOR_STORE_NUMBER'] = df['PRIOR_STORE_NUMBER'].astype('int8')

# %%
df.to_csv('final_dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563113 entries, 0 to 563112
# Data columns (total 45 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   STORE_KEY                         563113 non-null  int32
#  1   STORE_NUMBER                      563113 non-null  int16
#  2   STORE_NAME                        563113 non-null  object
#  3   STORE_TYPE_NAME                   563113 non-null  category
#  4   OPEN_DATE                         563113 non-null  datetime64[ns]
#  5   CLOSE_DATE                        563113 non-null  datetime64[ns]
#  6   BUSINESS_DATE                     563113 non-null  datetime64[ns]
#  7   CITY_NAME                         563113 non-null  category
#  8   STATE_CODE                        563113 non-null  category
#  9   STATE_NAME                        563113 non-null  category
#  10  TIME_ZONE_NAME                    563113 non-null  category
# ...

# %%
df
# Out:
#         STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE  \
# 0             825             2        TX2       FRANCHISE 1998-05-09
# 1             825             2        TX2       FRANCHISE 1998-05-09
# 2             825             2        TX2       FRANCHISE 1998-05-09
# 3             825             2        TX2       FRANCHISE 1998-05-09
# 4             825             2        TX2       FRANCHISE 1998-05-09
# ...           ...           ...        ...             ...        ...
# 563108        791          7005     OH7005       FRANCHISE 2020-10-12
# 563109        791          7005     OH7005       FRANCHISE 2020-10-12
# 563110        791          7005     OH7005       FRANCHISE 2020-10-12
# 563111        791          7005     OH7005       FRANCHISE 2020-10-12
# 563112        791          7005     OH7005       FRANCHISE 2020-10-12
#
#        CLOSE_DATE BUSINESS_DATE CITY_NAME STATE_CODE STATE_NAME  \
# ...

# %%
df['CITY_NAME'].nunique()
# Out:
# 327

# %%
df['AREA_REGION'].nunique()
# Out:
# 99

# %%
df['DMA_NAME'].nunique()
# Out:
# 98

# %%
month_name_index = 7
day_name_index = 8
month_name = df['BUSINESS_DATE'].dt.month_name()
day_name = df['BUSINESS_DATE'].dt.day_name()
df.insert(loc = month_name_index, column = 'MONTH_NAME', value = month_name)
df.insert(loc = day_name_index, column = 'DAY_NAME', value = day_name)
df
# Out:
#         STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE  \
# 0             825             2        TX2       FRANCHISE 1998-05-09
# 1             825             2        TX2       FRANCHISE 1998-05-09
# 2             825             2        TX2       FRANCHISE 1998-05-09
# 3             825             2        TX2       FRANCHISE 1998-05-09
# 4             825             2        TX2       FRANCHISE 1998-05-09
# ...           ...           ...        ...             ...        ...
# 563108        791          7005     OH7005       FRANCHISE 2020-10-12
# 563109        791          7005     OH7005       FRANCHISE 2020-10-12
# 563110        791          7005     OH7005       FRANCHISE 2020-10-12
# 563111        791          7005     OH7005       FRANCHISE 2020-10-12
# 563112        791          7005     OH7005       FRANCHISE 2020-10-12
#
#        CLOSE_DATE BUSINESS_DATE MONTH_NAME   DAY_NAME CITY_NAME STATE_CODE  \
# ...

# %%
# Convert the categorical columns to a common type (e.g., string) before comparison
df[df['DMA_NAME'].astype(str) != df['AREA_REGION'].astype(str)]
# Out:
#         STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE  \
# 561074        713          2407     CA2407       FRANCHISE 2023-12-11
# 561075        713          2407     CA2407       FRANCHISE 2023-12-11
# 561076        713          2407     CA2407       FRANCHISE 2023-12-11
# 561077        713          2407     CA2407       FRANCHISE 2023-12-11
# 561078        713          2407     CA2407       FRANCHISE 2023-12-11
# ...           ...           ...        ...             ...        ...
# 561539      77907          2490     LA2490       FRANCHISE 2023-11-08
# 561540      77907          2490     LA2490       FRANCHISE 2023-11-08
# 561541      77907          2490     LA2490       FRANCHISE 2023-11-08
# 561542      77907          2490     LA2490       FRANCHISE 2023-11-08
# 561543      77907          2490     LA2490       FRANCHISE 2023-11-08
#
#        CLOSE_DATE BUSINESS_DATE MONTH_NAME   DAY_NAME    CITY_NAME STATE_CODE  \
# ...

# %%
df[df['STORE_STATUS'] == 'INACTIVE']
# Out:
#         STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE  \
# 3428          830             7        TX7       FRANCHISE 1998-11-14
# 3429          830             7        TX7       FRANCHISE 1998-11-14
# 3430          830             7        TX7       FRANCHISE 1998-11-14
# 3431          830             7        TX7       FRANCHISE 1998-11-14
# 3432          830             7        TX7       FRANCHISE 1998-11-14
# ...           ...           ...        ...             ...        ...
# 563108        791          7005     OH7005       FRANCHISE 2020-10-12
# 563109        791          7005     OH7005       FRANCHISE 2020-10-12
# 563110        791          7005     OH7005       FRANCHISE 2020-10-12
# 563111        791          7005     OH7005       FRANCHISE 2020-10-12
# 563112        791          7005     OH7005       FRANCHISE 2020-10-12
#
#        CLOSE_DATE BUSINESS_DATE MONTH_NAME   DAY_NAME  CITY_NAME STATE_CODE  \
# ...

# %%
df
# Out:
#         STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE  \
# 0             825             2        TX2       FRANCHISE 1998-05-09
# 1             825             2        TX2       FRANCHISE 1998-05-09
# 2             825             2        TX2       FRANCHISE 1998-05-09
# 3             825             2        TX2       FRANCHISE 1998-05-09
# 4             825             2        TX2       FRANCHISE 1998-05-09
# ...           ...           ...        ...             ...        ...
# 563108        791          7005     OH7005       FRANCHISE 2020-10-12
# 563109        791          7005     OH7005       FRANCHISE 2020-10-12
# 563110        791          7005     OH7005       FRANCHISE 2020-10-12
# 563111        791          7005     OH7005       FRANCHISE 2020-10-12
# 563112        791          7005     OH7005       FRANCHISE 2020-10-12
#
#        CLOSE_DATE BUSINESS_DATE CITY_NAME STATE_CODE STATE_NAME  \
# ...

# %%
df[df['STORE_NUMBER'] == 2].sort_values('NET_SALES_FINAL_USD_AMOUNT', ascending = False).head(20)[['BUSINESS_DATE', 'CITY_NAME'.'STATE_NAME','DMA_NAME','TRANSACTION_FINAL_COUNT', 'NET_SALES_FINAL_USD_AMOUNT','PY_TRANSACTION_FINAL_COUNT','PY_NET_SALES_FINAL_USD_AMOUNT','PROMOTION_TYPE',
                                                                                                    'PROMOTION_OFFER', 'PROMOTION_CASH_AMOUNT', 'PLATFORM' ,  'FREQUENCY', 'PROMOTION_COVERAGE' ]]
# Out:
#      BUSINESS_DATE  TRANSACTION_FINAL_COUNT  NET_SALES_FINAL_USD_AMOUNT  \
# 682     2023-02-12                      294                        9334
# 55      2022-02-13                      218                        6950
# 659     2020-02-02                      255                        6496
# 1320    2021-02-07                      212                        6275
# 1582    2022-07-29                      280                        5514
# 681     2023-05-19                      247                        5405
# 1317    2022-01-16                      220                        5264
# 1149    2023-07-29                      271                        4990
# 1075    2022-01-22                      194                        4847
# 978     2023-03-17                      205                        4796
# 579     2022-09-02                      228                        4779
# 1699    2023-01-22                      195                        4754
# ...

# %%
def highs_data(store_number):
  return df[df['STORE_NUMBER'] == store_number].sort_values('NET_SALES_FINAL_USD_AMOUNT', ascending = False).head(20)[['BUSINESS_DATE','CITY_NAME','STATE_NAME', 'MONTH_NAME','DAY_NAME' ,'TRANSACTION_FINAL_COUNT', 'NET_SALES_FINAL_USD_AMOUNT','PY_TRANSACTION_FINAL_COUNT','PY_NET_SALES_FINAL_USD_AMOUNT','PROMOTION_TYPE',
                                                                                                    'PROMOTION_OFFER', 'PROMOTION_CASH_AMOUNT', 'PLATFORM' ,  'FREQUENCY', 'PROMOTION_COVERAGE' ]]

# %%
df['STORE_NUMBER'].value_counts().head(10)
# Out:
# STORE_NUMBER
# 2       1714
# 1066    1714
# 1003    1714
# 1012    1714
# 1019    1714
# 1022    1714
# 1023    1714
# 1024    1714
# 1049    1714
# 1051    1714
# Name: count, dtype: int64

# %%
import numpy as np

# %%
unique_store_numbers = df[df['STATE_NAME'] == 'TEXAS']['STORE_NUMBER'].unique()
random_store_number = np.random.choice(unique_store_numbers)
random_store_number
# Out:
# 808

# %%
highs_data(random_store_number)
# Out:
#        BUSINESS_DATE   CITY_NAME STATE_NAME MONTH_NAME DAY_NAME  \
# 248265    2023-11-03  PLEASANTON      TEXAS   November   Friday
# 248828    2023-02-12  PLEASANTON      TEXAS   February   Sunday
# 247710    2023-09-01  PLEASANTON      TEXAS  September   Friday
# 247711    2023-05-05  PLEASANTON      TEXAS        May   Friday
# 249158    2023-04-28  PLEASANTON      TEXAS      April   Friday
# 248279    2023-04-21  PLEASANTON      TEXAS      April   Friday
# 247867    2022-09-02  PLEASANTON      TEXAS  September   Friday
# 248607    2023-12-08  PLEASANTON      TEXAS   December   Friday
# 248197    2023-10-13  PLEASANTON      TEXAS    October   Friday
# 247650    2023-01-13  PLEASANTON      TEXAS    January   Friday
# 248925    2023-10-20  PLEASANTON      TEXAS    October   Friday
# 248634    2023-06-16  PLEASANTON      TEXAS       June   Friday
# 248845    2023-09-15  PLEASANTON      TEXAS  September   Friday
# 249155    2023-11-17  PLEASANTON      TEXAS   November   Friday
# ...

# %%
df[df['DMA_NAME'] == 'DALLAS-FT. WORTH']['STORE_NUMBER'].nunique()
# Out:
# 30

# %%
df[df['DMA_NAME'] == 'DALLAS-FT. WORTH'].sort_values('NET_SALES_FINAL_USD_AMOUNT', ascending = False).head(100)['BUSINESS_DATE'].value_counts().head(12)
# Out:
# BUSINESS_DATE
# 2023-02-12    12
# 2022-02-13     7
# 2021-02-07     7
# 2020-02-02     6
# 2023-01-22     5
# 2023-09-10     5
# 2022-01-16     3
# 2023-09-17     3
# 2023-12-10     3
# 2023-10-27     3
# 2023-09-24     3
# 2023-07-29     3
# Name: count, dtype: int64

# %%
df['DMA_NAME'].unique()
# Out:
# ['DALLAS-FT. WORTH', 'MONROE-EL DORADO', 'OKLAHOMA CITY', 'CHAMPAIGN&SPRNGFLD-DECATUR', 'HOUSTON', ..., 'SPOKANE', 'COLUMBIA, SC', 'NEW ORLEANS', 'GRAND RAPIDS-KALMZOO-B.CRK', 'ROCHESTER, NY']
# Length: 98
# Categories (98, object): ['ABILENE-SWEETWATER', 'ALBUQUERQUE-SANTA FE', 'ALEXANDRIA, LA', 'ANCHORAGE', ...,
#                           'WASHINGTON, DC (HAGRSTWN)', 'WEST PALM BEACH-FT. PIERCE', 'WICHITA FALLS & LAWTON',
#                           'WILMINGTON']

# %%
df.head(1)
# Out:
#    STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 0        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#   BUSINESS_DATE MONTH_NAME  DAY_NAME CITY_NAME STATE_CODE STATE_NAME  \
# 0    2022-11-17   November  Thursday    IRVING         TX      TEXAS
#
#   TIME_ZONE_NAME  DMA_ID          DMA_NAME STORE_STATUS  REGION_ID  \
# 0        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE          1
#
#   REGION_NAME  PRIOR_STORE_NUMBER STORE_LIVE_DATE STORE_FUNCTIONAL_STATUS  \
# 0   SOUTHWEST                   0      1998-05-09             OPERATIONAL
#
#   GLOBAL_REGION_NAME GLOBAL_REGION_STORE_TYPE_NAME       AREA_REGION  \
# 0           Domestic             DOMESTICFRANCHISE  DALLAS-FT. WORTH
#
#   DISPATCH_GO_LIVE_DATE DOOR_DASH_GO_LIVE_DATE DOOR_DASH_MARKUP_GO_LIVE_DATE  \
# 0            2019-04-17             2019-04-17                    2020-09-27
#
#   STORE_CONCEPT_NAME UBER_EATS_MARKUP_DATE  TEMP_CLOSE_INDICATOR  \
# ...

# %%
def most_sales_days(dma_name):
  print(f'DMA NAME: {dma_name}')
  return df[df['DMA_NAME'] == dma_name].sort_values('NET_SALES_FINAL_USD_AMOUNT', ascending = False).head(100)[['BUSINESS_DATE','MONTH_NAME','DAY_NAME','PROMOTION_TYPE','PROMOTION_OFFER','PROMOTION_ITEM','PROMOTION_CASH_AMOUNT','PROMOTION_PERCENTAGE','PLATFORM','FREQUENCY','PROMOTION_COVERAGE']].value_counts().head(25)

# %%
unique_store_numbers1 = df['DMA_NAME'].unique()
random_dma_name = np.random.choice(unique_store_numbers1)
random_dma_name
# Out:
# 'DAVENPORT-R.ISLAND-MOLINE'

# %%
most_sales_days(random_dma_name)
# Out:
# DMA NAME: DAVENPORT-R.ISLAND-MOLINE
# BUSINESS_DATE  MONTH_NAME  DAY_NAME   PROMOTION_TYPE  PROMOTION_OFFER  PROMOTION_ITEM    PROMOTION_CASH_AMOUNT  PROMOTION_PERCENTAGE  PLATFORM     FREQUENCY  PROMOTION_COVERAGE
# 2019-07-26     July        Friday     No Promotion    No Offers        No Items          0                      0.0                   No Platform  None       None                  1
# 2023-10-06     October     Friday     Free Item       Protein          Sandwich          0                      0.0                   UE           Daily      National              1
# 2023-10-27     October     Friday     No Promotion    No Offers        No Items          0                      0.0                   No Platform  None       None                  1
# 2023-10-26     October     Thursday   No Promotion    No Offers        No Items          0                      0.0                   No Platform  None       None                  1
# ...

# %% [markdown]
# # 22/07/2024

# %%
df
# Out:
#         STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE  \
# 0             825             2        TX2       FRANCHISE 1998-05-09
# 1             825             2        TX2       FRANCHISE 1998-05-09
# 2             825             2        TX2       FRANCHISE 1998-05-09
# 3             825             2        TX2       FRANCHISE 1998-05-09
# 4             825             2        TX2       FRANCHISE 1998-05-09
# ...           ...           ...        ...             ...        ...
# 563108        791          7005     OH7005       FRANCHISE 2020-10-12
# 563109        791          7005     OH7005       FRANCHISE 2020-10-12
# 563110        791          7005     OH7005       FRANCHISE 2020-10-12
# 563111        791          7005     OH7005       FRANCHISE 2020-10-12
# 563112        791          7005     OH7005       FRANCHISE 2020-10-12
#
#        CLOSE_DATE BUSINESS_DATE MONTH_NAME   DAY_NAME CITY_NAME STATE_CODE  \
# ...

# %%
df[df['STORE_STATUS'] == 'INACTIVE']['STORE_NUMBER'].unique()
# Out:
# array([   7,  600,  610,  785,  846, 7005], dtype=int16)

# %%
df['STORE_TYPE_NAME'].value_counts()
# Out:
# STORE_TYPE_NAME
# FRANCHISE    545974
# CORPORATE     17139
# Name: count, dtype: int64

# %%
df[df['STORE_TYPE_NAME'] == 'CORPORATE']['STORE_NUMBER'].unique()
# Out:
# array([ 72, 298, 534, 942, 947, 959, 968, 969, 977, 979, 997], dtype=int16)

# %%
df['DMA_NAME'].unique()
# Out:
# ['DALLAS-FT. WORTH', 'MONROE-EL DORADO', 'OKLAHOMA CITY', 'CHAMPAIGN&SPRNGFLD-DECATUR', 'HOUSTON', ..., 'SPOKANE', 'COLUMBIA, SC', 'NEW ORLEANS', 'GRAND RAPIDS-KALMZOO-B.CRK', 'ROCHESTER, NY']
# Length: 98
# Categories (98, object): ['ABILENE-SWEETWATER', 'ALBUQUERQUE-SANTA FE', 'ALEXANDRIA, LA', 'ANCHORAGE', ...,
#                           'WASHINGTON, DC (HAGRSTWN)', 'WEST PALM BEACH-FT. PIERCE', 'WICHITA FALLS & LAWTON',
#                           'WILMINGTON']

# %%
for dma_name in df['DMA_NAME'].unique():
  print(dma_name)
# Out:
# DALLAS-FT. WORTH
# MONROE-EL DORADO
# OKLAHOMA CITY
# CHAMPAIGN&SPRNGFLD-DECATUR
# HOUSTON
# ODESSA-MIDLAND
# TULSA
# COLORADO SPRINGS-PUEBLO
# DENVER
# AUGUSTA-AIKEN
# SHREVEPORT
# WICHITA FALLS & LAWTON
# MEMPHIS
# LAFAYETTE, LA
# LOS ANGELES
# LITTLE ROCK-PINE BLUFF
# LAREDO
# CLEVELAND-AKRON (CANTON)
# JACKSON, MS
# MIAMI-FT. LAUDERDALE
# TUCSON (SIERRA VISTA)
# WASHINGTON, DC (HAGRSTWN)
# HARLINGEN-WSLCO-BRNSVL-MCA
# SAN ANTONIO
# PADUCAH-CAPE GIRARD-HARSBG
# PHOENIX (PRESCOTT)
# MONTEREY-SALINAS
# BAKERSFIELD
# CORPUS CHRISTI
# SACRAMNTO-STKTON-MODESTO
# CHICAGO
# AUSTIN
# SAN FRANCISCO-OAK-SAN JOSE
# GREENVLL-SPART-ASHEVLL-AND
# ALBUQUERQUE-SANTA FE
# FRESNO-VISALIA
# MILWAUKEE
# ST. LOUIS
# COLUMBUS, OH
# BALTIMORE
# EL PASO (LAS CRUCES)
# KANSAS CITY
# CHARLOTTE
# SEATTLE-TACOMA
# HONOLULU
# NEW YORK
# MINNEAPOLIS-ST. PAUL
# LOUISVILLE
# COLUMBUS-TUPELO-W PNT-HSTN
# INDIANAPOLIS
# NASHVILLE
# SANTABARBRA-SANMAR-SANLUOB
# HARTFORD & NEW HAVEN
# JONESBORO
# BATON ROUGE
# ...

# %%
df[df['DMA_NAME'] == random_dma_name]['STORE_NUMBER'].nunique()
# Out:
# 30

# %%
df[df['DMA_NAME'] == random_dma_name]['STORE_NUMBER'].unique()
# Out:
# array([   2,    5,    7,   27,   51,   61,   72,  245,  249,  298,  340,
#         345,  391,  534,  538,  633,  727,  878,  947,  959,  968,  969,
#         997, 1012, 1065, 1132, 1235, 1468, 1729, 2255], dtype=int16)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def details(store_number):
  return df[df['STORE_NUMBER'] == store_number][['STORE_NUMBER','STORE_TYPE_NAME','OPEN_DATE','CLOSE_DATE','BUSINESS_DATE','MONTH_NAME','DAY_NAME','CITY_NAME','STATE_NAME','TIME_ZONE_NAME','DMA_NAME','STORE_STATUS','STORE_STATUS','DISPATCH_GO_LIVE_DATE',
                                                  'DOOR_DASH_GO_LIVE_DATE', 'DOOR_DASH_MARKUP_GO_LIVE_DATE','STORE_CONCEPT_NAME', 'UBER_EATS_MARKUP_DATE','TRANSACTION_FINAL_COUNT','NET_SALES_FINAL_USD_AMOUNT','PROMOTION_TYPE',
                                                  'PROMOTION_OFFER', 'PROMOTION_ITEM' , 'PROMOTION_CASH_AMOUNT' ,'PROMOTION_PERCENTAGE','PLATFORM','FREQUENCY','PROMOTION_COVERAGE']].sort_values('BUSINESS_DATE')

# %%
unique_store_numbers1 = df['DMA_NAME'].unique()
random_dma_name = np.random.choice(unique_store_numbers1)
random_dma_name
# Out:
# 'SALT LAKE CITY'

# %%
unique_store_numbers = df[df['DMA_NAME'] == random_dma_name]['STORE_NUMBER'].unique()
random_store_name_under_dma = np.random.choice(unique_store_numbers)
random_store_name_under_dma
# Out:
# 2552

# %%
def quant():
  # unique_store_numbers1 = df['DMA_NAME'].unique()
  # random_dma_name = np.random.choice(unique_store_numbers1)
  # print(random_dma_name)
  # unique_store_numbers = df[df['DMA_NAME'] == random_dma_name]['STORE_NUMBER'].unique()
  # random_store_name_under_dma = np.random.choice(unique_store_numbers)
  print(random_store_name_under_dma)
  temp_df = details(random_store_name_under_dma)
  sns.relplot(data=temp_df, x="BUSINESS_DATE", y="NET_SALES_FINAL_USD_AMOUNT", kind="line")
  return temp_df.groupby(temp_df['BUSINESS_DATE'].dt.year).apply(lambda x: x.nlargest(10, 'NET_SALES_FINAL_USD_AMOUNT'))[['NET_SALES_FINAL_USD_AMOUNT','BUSINESS_DATE','MONTH_NAME','DAY_NAME','PROMOTION_TYPE','PROMOTION_OFFER',
                                                                                                                          'PROMOTION_ITEM','PROMOTION_CASH_AMOUNT','PROMOTION_PERCENTAGE','PLATFORM','FREQUENCY',
                                                                                                                          'PROMOTION_COVERAGE']]

# %%
quant()
# Out:
# 2552
#                       NET_SALES_FINAL_USD_AMOUNT BUSINESS_DATE MONTH_NAME  \
# BUSINESS_DATE
# 2023          561564                        3786    2023-12-16   December
#               561562                        3653    2023-12-31   December
#               561555                        3468    2023-12-29   December
#               561557                        3296    2023-12-23   December
#               561572                        3245    2023-12-22   December
#               561567                        3117    2023-12-30   December
#               561559                        2580    2023-12-15   December
#               561568                        2522    2023-12-21   December
#               561570                        2212    2023-12-28   December
#               561566                        2091    2023-12-27   December
#
#                        DAY_NAME PROMOTION_TYPE PROMOTION_OFFER PROMOTION_ITEM  \
# BUSINESS_DATE
# ...

# %%
df[df['STORE_NUMBER'] == 751].groupby('PROMOTION_TYPE')[['TRANSACTION_FINAL_COUNT','NET_SALES_FINAL_USD_AMOUNT']].describe()
# Out:
#                  TRANSACTION_FINAL_COUNT                                       \
#                                    count        mean        std   min     25%
# PROMOTION_TYPE
# Delivery Fee                        57.0  155.754386  36.337348  19.0  135.00
# Free Item                          215.0  163.409302  35.213367  51.0  137.00
# No Promotion                      1360.0  148.033824  38.920198   0.0  126.00
# Overall Discount                    82.0  142.426829  34.492451   0.0  127.25
#
#                                       NET_SALES_FINAL_USD_AMOUNT               \
#                     50%    75%    max                      count         mean
# PROMOTION_TYPE
# Delivery Fee      159.0  175.0  226.0                       57.0  3200.473684
# Free Item         158.0  183.5  258.0                      215.0  3530.916279
# No Promotion      146.0  171.0  311.0                     1360.0  3023.862500
# ...

# %%
df['DMA_NAME'].value_counts()
# Out:
# DMA_NAME
# LOS ANGELES                   84980
# DALLAS-FT. WORTH              47528
# HOUSTON                       34040
# CHICAGO                       33078
# NEW YORK                      21858
#                               ...
# GRAND RAPIDS-KALMZOO-B.CRK      305
# SPOKANE                         257
# NEW ORLEANS                     141
# ROCHESTER, NY                    34
# INDIANAPOLIS                     27
# Name: count, Length: 98, dtype: int64

# %%
df['STATE_NAME'].nunique()
# Out:
# 38

# %%
df['CITY_NAME'].nunique()
# Out:
# 327

# %%
temp_df = df.groupby(['DMA_NAME', 'CITY_NAME'])['STORE_NUMBER'].count().reset_index()
temp_df.rename(columns={'STORE_NUMBER': 'STORE_COUNT'}, inplace=True)
temp_df[temp_df['STORE_COUNT'] !=0]
# Out:
#                          DMA_NAME        CITY_NAME  STORE_COUNT
# 0              ABILENE-SWEETWATER          ABILENE         1714
# 329          ALBUQUERQUE-SANTA FE      ALBUQUERQUE         1714
# 657                ALEXANDRIA, LA       ALEXANDRIA          714
# 987                     ANCHORAGE        ANCHORAGE         1714
# 1292                    ANCHORAGE          WASILLA         1714
# ...                           ...              ...          ...
# 31160  WEST PALM BEACH-FT. PIERCE      FORT PIERCE         1714
# 31181  WEST PALM BEACH-FT. PIERCE       GREENACRES         1714
# 31384  WEST PALM BEACH-FT. PIERCE  WEST PALM BEACH         1284
# 31712      WICHITA FALLS & LAWTON    WICHITA FALLS         1714
# 32040                  WILMINGTON       WILMINGTON         1714
#
# [334 rows x 3 columns]

# %%
temp_df[temp_df['STORE_COUNT'] > 1714]
# Out:
#                          DMA_NAME         CITY_NAME  STORE_COUNT
# 2308                  BAKERSFIELD       BAKERSFIELD         3428
# 4297                    CHARLOTTE         CHARLOTTE         4434
# 4954                      CHICAGO           CHICAGO        17140
# 6601                 COLUMBUS, OH          COLUMBUS         7205
# 7535             DALLAS-FT. WORTH         ARLINGTON         1835
# 7593             DALLAS-FT. WORTH            DALLAS        12702
# 7622             DALLAS-FT. WORTH            FRISCO         3428
# 7658             DALLAS-FT. WORTH            IRVING         3428
# 8192                       DENVER            AURORA         3428
# 8251                       DENVER            DENVER         2207
# 9241         EL PASO (LAS CRUCES)           EL PASO         4205
# 11480  HARLINGEN-WSLCO-BRNSVL-MCA       BROWNSVILLE         3428
# 11632  HARLINGEN-WSLCO-BRNSVL-MCA           MISSION         3428
# ...

# %%
df['DMA_NAME'].value_counts().head(20)
# Out:
# DMA_NAME
# LOS ANGELES                   84980
# DALLAS-FT. WORTH              47528
# HOUSTON                       34040
# CHICAGO                       33078
# NEW YORK                      21858
# SAN FRANCISCO-OAK-SAN JOSE    17455
# HARLINGEN-WSLCO-BRNSVL-MCA    13712
# ATLANTA                       12720
# PHOENIX (PRESCOTT)            12510
# SAN ANTONIO                   12240
# MIAMI-FT. LAUDERDALE          11998
# BOSTON (MANCHESTER)            8871
# WASHINGTON, DC (HAGRSTWN)      8724
# SALT LAKE CITY                 8326
# DENVER                         8066
# CLEVELAND-AKRON (CANTON)       7852
# COLUMBUS, OH                   7205
# ORLANDO-DAYTONA BCH-MELBRN     6885
# TAMPA-ST. PETE (SARASOTA)      6718
# DETROIT                        6457
# Name: count, dtype: int64

# %%
dma = 'LOS ANGELES'
df[df['DMA_NAME'] == 'LOS ANGELES']['STORE_NUMBER'].unique()
# Out:
# array([ 137,  237,  295,  296,  315,  386,  387,  392,  435,  443,  458,
#         465,  494,  511,  573,  584,  601,  605,  622,  625,  632,  672,
#         679,  725,  775,  806,  835,  856, 1051, 1078, 1081, 1143, 1169,
#        1206, 1229, 1232, 1315, 1346, 1357, 1415, 1416, 1484, 1566, 1567,
#        1576, 1637, 1700, 1752, 1806, 1913, 1942, 1975, 2301, 2311, 2364,
#        2574], dtype=int16)

# %%
store_number =  np.random.choice(df[df['DMA_NAME'] == 'LOS ANGELES']['STORE_NUMBER'].unique())
store_number
# Out:
# 1346

# %%
df_store = df[df['STORE_NUMBER'] == store_number].groupby(df[df['STORE_NUMBER'] == store_number]['BUSINESS_DATE'].dt.year).apply(lambda x: x.nlargest(10, 'NET_SALES_FINAL_USD_AMOUNT'))[['NET_SALES_FINAL_USD_AMOUNT','BUSINESS_DATE','MONTH_NAME','DAY_NAME','PROMOTION_TYPE','PROMOTION_OFFER',
                                                                                                                          'PROMOTION_ITEM','PROMOTION_CASH_AMOUNT','PROMOTION_PERCENTAGE','PLATFORM','FREQUENCY',
                                                                                                                          'PROMOTION_COVERAGE']]
df_store
# Out:
#                       NET_SALES_FINAL_USD_AMOUNT BUSINESS_DATE MONTH_NAME  \
# BUSINESS_DATE
# 2019          399423                        4231    2019-07-29       July
#               399588                        3750    2019-08-17     August
#               399382                        3668    2019-08-09     August
#               400048                        3640    2019-05-17        May
#               399334                        3637    2019-12-31   December
#               399299                        3636    2019-11-08   November
#               399616                        3634    2019-05-24        May
#               398896                        3593    2019-05-25        May
#               400352                        3578    2019-09-20  September
#               399460                        3565    2019-05-30        May
# 2020          400081                        7463    2020-02-02   February
# ...

# %%
holidays_and_events_2019 = [
    '2019-01-01',  # New Year's Day
    '2019-01-21',  # Martin Luther King Jr. Day
    '2019-02-03',  # Super Bowl Sunday
    '2019-02-14',  # Valentine's Day
    '2019-02-18',  # Presidents' Day
    '2019-03-17',  # St. Patrick's Day
    '2019-04-21',  # Easter Sunday
    '2019-05-12',  # Mother's Day
    '2019-05-27',  # Memorial Day
    '2019-06-16',  # Father's Day
    '2019-07-04',  # Independence Day
    '2019-09-02',  # Labor Day
    '2019-10-14',  # Columbus Day
    '2019-10-31',  # Halloween
    '2019-11-11',  # Veterans Day
    '2019-11-28',  # Thanksgiving Day
    '2019-11-29',  # Black Friday
    '2019-11-30',  # Small Business Saturday
    '2019-12-02',  # Cyber Monday
    '2019-12-24',  # Christmas Eve
    '2019-12-25',  # Christmas Day
    '2019-12-31'   # New Year's Eve
]
holidays_and_events_2020 = [
    '2020-01-01',  # New Year's Day
    '2020-01-20',  # Martin Luther King Jr. Day
    '2020-02-02',  # Super Bowl Sunday
    '2020-02-14',  # Valentine's Day
    '2020-02-17',  # Presidents' Day
    '2020-03-17',  # St. Patrick's Day
    '2020-04-12',  # Easter Sunday
    '2020-05-10',  # Mother's Day
    '2020-05-25',  # Memorial Day
    '2020-06-21',  # Father's Day
    '2020-07-04',  # Independence Day
    '2020-09-07',  # Labor Day
    '2020-10-12',  # Columbus Day
    '2020-10-31',  # Halloween
    '2020-11-11',  # Veterans Day
    '2020-11-26',  # Thanksgiving Day
    '2020-11-27',  # Black Friday
    '2020-11-28',  # Small Business Saturday
    '2020-11-30',  # Cyber Monday
    '2020-12-24',  # Christmas Eve
    '2020-12-25',  # Christmas Day
    '2020-12-31'   # New Year's Eve
]

holidays_and_events_2021 = [
    '2021-01-01',  # New Year's Day
    '2021-01-18',  # Martin Luther King Jr. Day
    '2021-02-07',  # Super Bowl Sunday
    '2021-02-14',  # Valentine's Day
    '2021-02-15',  # Presidents' Day
    '2021-03-17',  # St. Patrick's Day
    '2021-04-04',  # Easter Sunday
    '2021-05-09',  # Mother's Day
    '2021-05-31',  # Memorial Day
    '2021-06-20',  # Father's Day
    '2021-07-04',  # Independence Day
    '2021-09-06',  # Labor Day
    '2021-10-11',  # Columbus Day
    '2021-10-31',  # Halloween
    '2021-11-11',  # Veterans Day
    '2021-11-25',  # Thanksgiving Day
    '2021-11-26',  # Black Friday
    '2021-11-27',  # Small Business Saturday
    '2021-11-29',  # Cyber Monday
    '2021-12-24',  # Christmas Eve
    '2021-12-25',  # Christmas Day
    '2021-12-31'   # New Year's Eve
]

holidays_and_events_2022 = [
    '2022-01-01',  # New Year's Day
    '2022-01-17',  # Martin Luther King Jr. Day
    '2022-02-13',  # Super Bowl Sunday
    '2022-02-14',  # Valentine's Day
    '2022-02-21',  # Presidents' Day
    '2022-03-17',  # St. Patrick's Day
    '2022-04-17',  # Easter Sunday
    '2022-05-08',  # Mother's Day
    '2022-05-30',  # Memorial Day
    '2022-06-19',  # Father's Day
    '2022-07-04',  # Independence Day
    '2022-09-05',  # Labor Day
    '2022-10-10',  # Columbus Day
    '2022-10-31',  # Halloween
    '2022-11-11',  # Veterans Day
    '2022-11-24',  # Thanksgiving Day
    '2022-11-25',  # Black Friday
    '2022-11-26',  # Small Business Saturday
    '2022-11-28',  # Cyber Monday
    '2022-12-24',  # Christmas Eve
    '2022-12-25',  # Christmas Day
    '2022-12-31'   # New Year's Eve
]

holidays_and_events_2023 = [
    '2023-01-01',  # New Year's Day
    '2023-01-16',  # Martin Luther King Jr. Day
    '2023-02-12',  # Super Bowl Sunday
    '2023-02-14',  # Valentine's Day
    '2023-02-20',  # Presidents' Day
    '2023-03-17',  # St. Patrick's Day
    '2023-04-09',  # Easter Sunday
    '2023-05-14',  # Mother's Day
    '2023-05-29',  # Memorial Day
    '2023-06-18',  # Father's Day
    '2023-07-04',  # Independence Day
    '2023-09-04',  # Labor Day
    '2023-10-09',  # Columbus Day
    '2023-10-31',  # Halloween
    '2023-11-11',  # Veterans Day
    '2023-11-23',  # Thanksgiving Day
    '2023-11-24',  # Black Friday
    '2023-11-25',  # Small Business Saturday
    '2023-11-27',  # Cyber Monday
    '2023-12-24',  # Christmas Eve
    '2023-12-25',  # Christmas Day
    '2023-12-31'   # New Year's Eve
]
# Convert to datetime
all_holidays_and_events = holidays_and_events_2019.copy()
all_holidays_and_events.extend(holidays_and_events_2020)
all_holidays_and_events.extend(holidays_and_events_2021)
all_holidays_and_events.extend(holidays_and_events_2022)
all_holidays_and_events.extend(holidays_and_events_2023)
all_holidays_and_events = pd.DatetimeIndex(all_holidays_and_events)

# %%
df_store[df_store['BUSINESS_DATE'].isin(all_holidays_and_events)]
# Out:
#                       NET_SALES_FINAL_USD_AMOUNT BUSINESS_DATE MONTH_NAME  \
# BUSINESS_DATE
# 2019          399334                        3637    2019-12-31   December
# 2020          400081                        7463    2020-02-02   February
#               399915                        7310    2020-12-31   December
#               400173                        5625    2020-10-31    October
# 2021          398998                        9850    2021-02-07   February
#               398764                        6169    2021-01-01    January
# 2022          398966                        9126    2022-02-13   February
#               398699                        7320    2022-12-31   December
# 2023          400092                       12132    2023-02-12   February
#
#                       DAY_NAME PROMOTION_TYPE PROMOTION_OFFER PROMOTION_ITEM  \
# BUSINESS_DATE
# 2019          399334   Tuesday   No Promotion       No Offers       No Items
# ...

# %%
df_saved = df.copy()

# %%
df.head(1)
# Out:
#    STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE CLOSE_DATE  \
# 0        825             2        TX2       FRANCHISE 1998-05-09 1999-12-31
#
#   BUSINESS_DATE MONTH_NAME  DAY_NAME CITY_NAME STATE_CODE STATE_NAME  \
# 0    2022-11-17   November  Thursday    IRVING         TX      TEXAS
#
#   TIME_ZONE_NAME  DMA_ID          DMA_NAME STORE_STATUS  REGION_ID  \
# 0        CENTRAL     623  DALLAS-FT. WORTH       ACTIVE          1
#
#   REGION_NAME  PRIOR_STORE_NUMBER STORE_LIVE_DATE STORE_FUNCTIONAL_STATUS  \
# 0   SOUTHWEST                   0      1998-05-09             OPERATIONAL
#
#   GLOBAL_REGION_NAME GLOBAL_REGION_STORE_TYPE_NAME       AREA_REGION  \
# 0           Domestic             DOMESTICFRANCHISE  DALLAS-FT. WORTH
#
#   DISPATCH_GO_LIVE_DATE DOOR_DASH_GO_LIVE_DATE DOOR_DASH_MARKUP_GO_LIVE_DATE  \
# 0            2019-04-17             2019-04-17                    2020-09-27
#
#   STORE_CONCEPT_NAME UBER_EATS_MARKUP_DATE  TEMP_CLOSE_INDICATOR  \
# ...

# %%
temp = df[df['STORE_NUMBER'] == 1346].select_dtypes(include=['number']).groupby(['BUSINESS_DATE_FISCAL_YEAR','MONTH_NAME'])[['TRANSACTION_FINAL_COUNT','NET_SALES_FINAL_USD_AMOUNT','PY_TRANSACTION_FINAL_COUNT','PY_NET_SALES_FINAL_USD_AMOUNT']].mean()
temp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9c9540a50d9c> in <cell line: 1>()
# ----> 1 temp = df[df['STORE_NUMBER'] == 1346].select_dtypes(include=['number']).groupby(['BUSINESS_DATE_FISCAL_YEAR','MONTH_NAME'])[['TRANSACTION_FINAL_COUNT','NET_SALES_FINAL_USD_AMOUNT','PY_TRANSACTION_FINAL_COUNT','PY_NET_SALES_FINAL_USD_AMOUNT']].mean()
#       2 temp
#
# NameError: name 'df' is not defined

# %%
df[df['PROMOTION_TYPE'] != 'No Promotion']
# Out:
#         STORE_KEY  STORE_NUMBER STORE_NAME STORE_TYPE_NAME  OPEN_DATE  \
# 0             825             2        TX2       FRANCHISE 1998-05-09
# 1             825             2        TX2       FRANCHISE 1998-05-09
# 2             825             2        TX2       FRANCHISE 1998-05-09
# 3             825             2        TX2       FRANCHISE 1998-05-09
# 5             825             2        TX2       FRANCHISE 1998-05-09
# ...           ...           ...        ...             ...        ...
# 563037        791          7005     OH7005       FRANCHISE 2020-10-12
# 563048        791          7005     OH7005       FRANCHISE 2020-10-12
# 563091        791          7005     OH7005       FRANCHISE 2020-10-12
# 563095        791          7005     OH7005       FRANCHISE 2020-10-12
# 563102        791          7005     OH7005       FRANCHISE 2020-10-12
#
#        CLOSE_DATE BUSINESS_DATE MONTH_NAME  DAY_NAME CITY_NAME STATE_CODE  \
# ...

# %%
plt.figure(figsize=(12,8))
sns.lineplot(data = temp, x = 'BUSINESS_DATE_FISCAL_YEAR' , y = 'TRANSACTION_FINAL_COUNT', hue = 'MONTH_NAME')
# Out:
# <Axes: xlabel='BUSINESS_DATE_FISCAL_YEAR', ylabel='TRANSACTION_FINAL_COUNT'>

# %%
df[df['STORE_NUMBER'] == 1346].groupby('PROMOTION_TYPE')['BUSINESS_DATE_FISCAL_YEAR'].value_counts()
# Out:
# PROMOTION_TYPE    BUSINESS_DATE_FISCAL_YEAR
# Delivery Fee      2021                          29
#                   2022                          22
#                   2023                           6
#                   2019                           0
#                   2020                           0
#                   2024                           0
# Free Item         2023                         193
#                   2022                          22
#                   2024                           0
#                   2021                           0
#                   2020                           0
#                   2019                           0
# No Promotion      2020                         364
#                   2021                         335
#                   2022                         306
#                   2019                         250
#                   2023                         104
#                   2024                           1
# ...

# %%
df[df['STORE_NUMBER'] == 1346].groupby('PROMOTION_TYPE')['NET_SALES_FINAL_USD_AMOUNT'].describe()
# Out:
#                    count         mean          std     min      25%     50%  \
# PROMOTION_TYPE
# Delivery Fee        57.0  4676.070175   925.032352  2565.0  4071.00  4580.0
# Free Item          215.0  5148.093023  1111.595364  3046.0  4271.00  4976.0
# No Promotion      1360.0  3886.688235  1207.947758     0.0  3105.25  3848.0
# Overall Discount    82.0  4730.426829  1187.705237     0.0  4012.75  4694.5
#
#                       75%      max
# PROMOTION_TYPE
# Delivery Fee      5292.00   6671.0
# Free Item         6047.00   8081.0
# No Promotion      4661.25  12132.0
# Overall Discount  5406.75   7563.0

# %%
df[(df['STORE_NUMBER'] == 1346) & df['NET_SALES_FINAL_USD_AMOUNT'] > 0].groupby(['PROMOTION_TYPE', 'BUSINESS_DATE_FISCAL_YEAR'])['NET_SALES_FINAL_USD_AMOUNT'].describe()
# Out:
#                                             count         mean          std  \
# PROMOTION_TYPE   BUSINESS_DATE_FISCAL_YEAR
# Delivery Fee     2021                        16.0  4774.875000  1093.415802
#                  2022                        12.0  4685.166667  1059.686903
#                  2023                         4.0  5254.000000   918.108926
# Free Item        2022                        16.0  4986.750000   790.864127
#                  2023                        80.0  5340.750000  1204.004137
# No Promotion     2019                       135.0  2517.148148   475.854150
#                  2020                       168.0  3764.880952   928.615858
#                  2021                       173.0  4392.028902   828.867274
#                  2022                       158.0  4356.417722   980.196141
#                  2023                        53.0  4864.660377  1258.524028
#                  2024                         1.0  5739.000000          NaN
# ...

# %%
df[(df['STORE_NUMBER'] == 1346) & df['NET_SALES_FINAL_USD_AMOUNT'] > 0].groupby(['PROMOTION_ITEM', 'BUSINESS_DATE_FISCAL_YEAR'])['NET_SALES_FINAL_USD_AMOUNT'].describe()
# Out:
#                                             count         mean          std  \
# PROMOTION_ITEM   BUSINESS_DATE_FISCAL_YEAR
# All Items        2022                         7.0  4323.285714  1014.206047
#                  2023                        26.0  5048.153846  1131.229444
# Brownie          2023                         4.0  6275.500000  1778.970020
# Chicken Sandwich 2022                        13.0  4931.615385   849.693037
#                  2023                        22.0  5510.272727  1136.043518
# Corn             2023                         2.0  5951.000000  1176.625684
# Delivery Fee     2021                        16.0  4774.875000  1093.415802
#                  2022                        12.0  4685.166667  1059.686903
#                  2023                         4.0  5254.000000   918.108926
# Fries            2022                         3.0  5225.666667   503.731410
#                  2023                        38.0  5269.315789  1202.512642
# ...

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data = df[df['STORE_NUMBER'] == 1346].groupby(['PROMOTION_ITEM', 'BUSINESS_DATE_FISCAL_YEAR'])['NET_SALES_FINAL_USD_AMOUNT'].describe() , x = 'BUSINESS_DATE_FISCAL_YEAR',  y = 'mean', hue = 'PROMOTION_ITEM')
# Out:
# <Axes: xlabel='BUSINESS_DATE_FISCAL_YEAR', ylabel='mean'>

# %%
df[(df['STORE_NUMBER'] == 1346)].groupby('PROMOTION_ITEM')['BUSINESS_DATE_FISCAL_YEAR'].value_counts()
# Out:
# PROMOTION_ITEM    BUSINESS_DATE_FISCAL_YEAR
# All Items         2023                          61
#                   2022                          21
#                   2019                           0
#                   2021                           0
#                   2024                           0
#                   2020                           0
# Brownie           2023                           7
#                   2019                           0
#                   2020                           0
#                   2021                           0
#                   2022                           0
#                   2024                           0
# Chicken Sandwich  2023                          53
#                   2022                          19
#                   2019                           0
#                   2020                           0
#                   2021                           0
#                   2024                           0
# ...

# %%
sns.barplot(data = df[df['STORE_NUMBER'] == 1346].groupby(['PROMOTION_OFFER', 'BUSINESS_DATE_FISCAL_YEAR'])['NET_SALES_FINAL_USD_AMOUNT'].describe() , x = 'BUSINESS_DATE_FISCAL_YEAR',  y = 'mean', hue = 'PROMOTION_OFFER')
# Out:
# <Axes: xlabel='BUSINESS_DATE_FISCAL_YEAR', ylabel='mean'>

# %%
df[(df['STORE_NUMBER'] == 1346) & (df['NET_SALES_FINAL_USD_AMOUNT'] != 0 )].groupby('PROMOTION_OFFER')['NET_SALES_FINAL_USD_AMOUNT'].mean()
# Out:
# PROMOTION_OFFER
# Delivery            4676.070175
# Dessert             5672.285714
# No Offers           3912.580311
# Overall Discount    4788.827160
# Protein             5228.352381
# Side                5030.650485
# Name: NET_SALES_FINAL_USD_AMOUNT, dtype: float64

# %%
sns.barplot(data = df[(df['STORE_NUMBER'] == 1346) & (df['NET_SALES_FINAL_USD_AMOUNT'] != 0 )].groupby('PROMOTION_OFFER')['NET_SALES_FINAL_USD_AMOUNT'].describe() , x = df[(df['STORE_NUMBER'] == 1346) & (df['NET_SALES_FINAL_USD_AMOUNT'] != 0 )].groupby('PROMOTION_OFFER')['NET_SALES_FINAL_USD_AMOUNT'].describe().index,  y = df[df['STORE_NUMBER'] == 1346].groupby('PROMOTION_OFFER')['NET_SALES_FINAL_USD_AMOUNT'].describe()['mean'])
# Out:
# <Axes: xlabel='PROMOTION_OFFER', ylabel='mean'>

# %%
df[(df['STORE_NUMBER'] == 1346) & ((df['NET_SALES_FINAL_USD_AMOUNT'] != 0 ))].groupby('PROMOTION_ITEM')['NET_SALES_FINAL_USD_AMOUNT'].describe()
# Out:
#                    count         mean          std     min      25%     50%  \
# PROMOTION_ITEM
# All Items           81.0  4788.827160  1070.098977  2822.0  4042.00  4700.0
# Brownie              7.0  5672.285714  1523.359633  4013.0  4463.00  5678.0
# Chicken Sandwich    72.0  5302.152778  1105.194096  3060.0  4454.25  5277.5
# Corn                 4.0  5618.000000   865.197858  4828.0  5046.25  5430.5
# Delivery Fee        57.0  4676.070175   925.032352  2565.0  4071.00  4580.0
# Fries               99.0  5006.919192  1079.916745  3046.0  4091.50  4891.0
# No Items          1351.0  3912.580311  1169.395359   595.0  3129.00  3859.0
# Sandwich            33.0  5067.333333  1125.579453  3533.0  4274.00  4718.0
#
#                       75%      max
# PROMOTION_ITEM
# All Items         5415.00   7563.0
# Brownie           6504.00   8081.0
# Chicken Sandwich  6155.25   7719.0
# Corn              6002.25   6783.0
# Delivery Fee      5292.00   6671.0
# Fries             5769.50   7803.0
# ...

# %%
sns.barplot(data =df[(df['STORE_NUMBER'] == 1346) & ((df['NET_SALES_FINAL_USD_AMOUNT'] != 0 ))].groupby('PROMOTION_ITEM')['NET_SALES_FINAL_USD_AMOUNT'].describe() , x = df[(df['STORE_NUMBER'] == 1346) & (df['NET_SALES_FINAL_USD_AMOUNT'] != 0 )].groupby('PROMOTION_ITEM')['NET_SALES_FINAL_USD_AMOUNT'].describe().index,  y = df[df['STORE_NUMBER'] == 1346].groupby('PROMOTION_ITEM')['NET_SALES_FINAL_USD_AMOUNT'].describe()['mean'])
# Out:
# <Axes: xlabel='PROMOTION_ITEM', ylabel='mean'>

# %%
df[(df['STORE_NUMBER'] == 1346)]['PROMOTION_OFFER'].value_counts()
# Out:
# PROMOTION_OFFER
# No Offers           1360
# Protein              105
# Side                 103
# Overall Discount      82
# Delivery              57
# Dessert                7
# Name: count, dtype: int64

# %%
# @title DAY_NAME

from matplotlib import pyplot as plt
import seaborn as sns
df_store.groupby('DAY_NAME').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
